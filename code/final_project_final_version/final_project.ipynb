# %%
import pandas as pd
from weibo import weibo90s
from weibo import weibofans30
from pyecharts import Bar, Line, Graph, Overlap, WordCloud, EffectScatter
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "/Users/linhuiqing/venv/lib/python3.7/site-packages/lml/utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'

# %%
df_tw = pd.read_csv('dataset/results_tw.csv', encoding = 'gbk').fillna('')
df_hk = pd.read_csv('dataset/results_hk.csv', encoding = 'gbk').fillna('')
df_ml = pd.read_csv('dataset/results_ml.csv', encoding = 'gbk').fillna('')

# %%
df_concat = pd.concat([df_tw, df_hk, df_ml], ignore_index = True).drop_duplicates()

# %% [markdown]
# # 1

# %%
def year_quantity(df):
    years = []
    numbers = []
    for i in df['年份'].drop_duplicates().sort_values():
        tmp = df[df['年份'] == i]
        years.append(i)
        numbers.append(len(tmp))
    results = pd.DataFrame({'年份': years, '总部数': numbers})
    return results

# %%
def year_quality(df):
    years = []
    scores = []
    for i in df['年份'].drop_duplicates().sort_values():
        tmp = df[df['年份'] == i]
        score = tmp['豆瓣评分'].sum() / len(tmp)
        years.append(i)
        scores.append(round(score, 2))
    results = pd.DataFrame({'年份': years, '平均分': scores})
    return results

# %%
def display_line(df, area):
    x = df['年份'].drop_duplicates().sort_values().apply(str)
    y1 = year_quantity(df)['总部数']
    y2 = year_quality(df)['平均分']
    line = Line(area)
    line.add('总部数', x, y1, mark_line = ['average'])
    line.add('平均分', x, y2, mark_line = ['average'])
    return line

# %%
display_line(df_tw, '台湾')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fd93e72e1a1d4a71a8c88213ec38d17a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fd93e72e1a1d4a71a8c88213ec38d17a = echarts.init(document.getElementById('fd93e72e1a1d4a71a8c88213ec38d17a'), 'light', {renderer: 'canvas'});
#
# var option_fd93e72e1a1d4a71a8c88213ec38d17a = {
#     "title": [
#         {
#             "text": "\u53f0\u6e7e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5236623,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1984",
#                     8
#                 ],
#                 [
#                     "1985",
#                     9
#                 ],
#                 [
#                     "1986",
#                     7
#                 ],
#                 [
#                     "1987",
#                     6
#                 ],
#                 [
#                     "1988",
#                     9
#                 ],
#                 [
#                     "1989",
#                     5
#                 ],
#                 [
#                     "1990",
#                     14
#                 ],
#                 [
#                     "1991",
#                     9
#                 ],
#                 [
#                     "1992",
#                     13
#                 ],
#                 [
#                     "1993",
#                     13
#                 ],
#                 [
#                     "1994",
#                     10
#                 ],
#                 [
#                     "1995",
#                     17
#                 ],
#                 [
#                     "1996",
#                     18
#                 ],
#                 [
#                     "1997",
#                     10
#                 ],
#                 [
#                     "1998",
#                     14
#                 ],
#                 [
#                     "1999",
#                     17
#                 ],
#                 [
#                     "2000",
#                     20
#                 ],
#                 [
#                     "2001",
#                     24
#                 ],
#                 [
#                     "2002",
#                     23
#                 ],
#                 [
#                     "2003",
#                     30
#                 ],
#                 [
#                     "2004",
#                     32
#                 ],
#                 [
#                     "2005",
#                     35
#                 ],
#                 [
#                     "2006",
#                     36
#                 ],
#                 [
#                     "2007",
#                     31
#                 ],
#                 [
#                     "2008",
#                     21
#                 ],
#                 [
#                     "2009",
#                     34
#                 ],
#                 [
#                     "2010",
#                     37
#                 ],
#                 [
#                     "2011",
#                     39
#                 ],
#                 [
#                     "2012",
#                     34
#                 ],
#                 [
#                     "2013",
#                     39
#                 ],
#                 [
#                     "2014",
#                     31
#                 ],
#                 [
#                     "2015",
#                     28
#                 ],
#                 [
#                     "2016",
#                     27
#                 ],
#                 [
#                     "2017",
#                     25
#                 ],
#                 [
#                     "2018",
#                     15
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5236623
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1984",
#                     7.44
#                 ],
#                 [
#                     "1985",
#                     7.52
#                 ],
#                 [
#                     "1986",
#                     7.57
#                 ],
#                 [
#                     "1987",
#                     7.38
#                 ],
#                 [
#                     "1988",
#                     7.44
#                 ],
#                 [
#                     "1989",
#                     7.38
#                 ],
#                 [
#                     "1990",
#                     7.34
#                 ],
#                 [
#                     "1991",
#                     7.83
#                 ],
#                 [
#                     "1992",
#                     7.86
#                 ],
#                 [
#                     "1993",
#                     7.74
#                 ],
#                 [
#                     "1994",
#                     7.45
#                 ],
#                 [
#                     "1995",
#                     7.33
#                 ],
#                 [
#                     "1996",
#                     7.58
#                 ],
#                 [
#                     "1997",
#                     7.25
#                 ],
#                 [
#                     "1998",
#                     7.35
#                 ],
#                 [
#                     "1999",
#                     6.99
#                 ],
#                 [
#                     "2000",
#                     7.09
#                 ],
#                 [
#                     "2001",
#                     7.07
#                 ],
#                 [
#                     "2002",
#                     6.62

# %%
display_line(df_hk, '香港')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0834b62aef3840bb905adb38d5bccc6d" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0834b62aef3840bb905adb38d5bccc6d = echarts.init(document.getElementById('0834b62aef3840bb905adb38d5bccc6d'), 'light', {renderer: 'canvas'});
#
# var option_0834b62aef3840bb905adb38d5bccc6d = {
#     "title": [
#         {
#             "text": "\u9999\u6e2f",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7960230,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     3
#                 ],
#                 [
#                     "1977",
#                     2
#                 ],
#                 [
#                     "1978",
#                     6
#                 ],
#                 [
#                     "1979",
#                     5
#                 ],
#                 [
#                     "1980",
#                     12
#                 ],
#                 [
#                     "1981",
#                     12
#                 ],
#                 [
#                     "1982",
#                     11
#                 ],
#                 [
#                     "1983",
#                     10
#                 ],
#                 [
#                     "1984",
#                     17
#                 ],
#                 [
#                     "1985",
#                     18
#                 ],
#                 [
#                     "1986",
#                     9
#                 ],
#                 [
#                     "1987",
#                     7
#                 ],
#                 [
#                     "1988",
#                     13
#                 ],
#                 [
#                     "1989",
#                     20
#                 ],
#                 [
#                     "1990",
#                     23
#                 ],
#                 [
#                     "1991",
#                     20
#                 ],
#                 [
#                     "1992",
#                     23
#                 ],
#                 [
#                     "1993",
#                     33
#                 ],
#                 [
#                     "1994",
#                     33
#                 ],
#                 [
#                     "1995",
#                     32
#                 ],
#                 [
#                     "1996",
#                     33
#                 ],
#                 [
#                     "1997",
#                     39
#                 ],
#                 [
#                     "1998",
#                     36
#                 ],
#                 [
#                     "1999",
#                     31
#                 ],
#                 [
#                     "2000",
#                     35
#                 ],
#                 [
#                     "2001",
#                     33
#                 ],
#                 [
#                     "2002",
#                     29
#                 ],
#                 [
#                     "2003",
#                     35
#                 ],
#                 [
#                     "2004",
#                     35
#                 ],
#                 [
#                     "2005",
#                     43
#                 ],
#                 [
#                     "2006",
#                     40
#                 ],
#                 [
#                     "2007",
#                     27
#                 ],
#                 [
#                     "2008",
#                     35
#                 ],
#                 [
#                     "2009",
#                     26
#                 ],
#                 [
#                     "2010",
#                     31
#                 ],
#                 [
#                     "2011",
#                     25
#                 ],
#                 [
#                     "2012",
#                     30
#                 ],
#                 [
#                     "2013",
#                     24
#                 ],
#                 [
#                     "2014",
#                     32
#                 ],
#                 [
#                     "2015",
#                     30
#                 ],
#                 [
#                     "2016",
#                     32
#                 ],
#                 [
#                     "2017",
#                     26
#                 ],
#                 [
#                     "2018",
#                     20
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 7960230
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     7.43
#                 ],
#                 [
#                     "1977",
#                     7.45
#                 ],
#                 [
#                     "1978",
#                     7.83
#                 ],
#                 [
#                     "1979",
#                     7.92
#                 ],
#                 [
#                     "1980",
#                     8.36
#                 ],
#                 [
#                     "1981",
#                     7.88
#                 ],
#                 [
#                     "1982",
#                     7.43
#                 ],
#                 [
#                     "1983",
#                     7.69
#                 ],
#                 [
#                     "1984",
#                     7.46
#                 ],
#                 [
#                     "1985",
#                     7.27
#                 ],
#                 [
#                     "1986",
#                     7.69
#                 ],

# %%
display_line(df_ml, '大陆')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f2e4cde13d5d4451bbc0af6ffef2e798" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f2e4cde13d5d4451bbc0af6ffef2e798 = echarts.init(document.getElementById('f2e4cde13d5d4451bbc0af6ffef2e798'), 'light', {renderer: 'canvas'});
#
# var option_f2e4cde13d5d4451bbc0af6ffef2e798 = {
#     "title": [
#         {
#             "text": "\u5927\u9646",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1434661,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1978",
#                     1
#                 ],
#                 [
#                     "1981",
#                     1
#                 ],
#                 [
#                     "1982",
#                     4
#                 ],
#                 [
#                     "1983",
#                     1
#                 ],
#                 [
#                     "1984",
#                     5
#                 ],
#                 [
#                     "1985",
#                     9
#                 ],
#                 [
#                     "1986",
#                     13
#                 ],
#                 [
#                     "1987",
#                     12
#                 ],
#                 [
#                     "1988",
#                     11
#                 ],
#                 [
#                     "1989",
#                     8
#                 ],
#                 [
#                     "1990",
#                     13
#                 ],
#                 [
#                     "1991",
#                     17
#                 ],
#                 [
#                     "1992",
#                     18
#                 ],
#                 [
#                     "1993",
#                     18
#                 ],
#                 [
#                     "1994",
#                     29
#                 ],
#                 [
#                     "1995",
#                     48
#                 ],
#                 [
#                     "1996",
#                     59
#                 ],
#                 [
#                     "1997",
#                     56
#                 ],
#                 [
#                     "1998",
#                     55
#                 ],
#                 [
#                     "1999",
#                     68
#                 ],
#                 [
#                     "2000",
#                     93
#                 ],
#                 [
#                     "2001",
#                     131
#                 ],
#                 [
#                     "2002",
#                     125
#                 ],
#                 [
#                     "2003",
#                     147
#                 ],
#                 [
#                     "2004",
#                     175
#                 ],
#                 [
#                     "2005",
#                     173
#                 ],
#                 [
#                     "2006",
#                     177
#                 ],
#                 [
#                     "2007",
#                     191
#                 ],
#                 [
#                     "2008",
#                     189
#                 ],
#                 [
#                     "2009",
#                     244
#                 ],
#                 [
#                     "2010",
#                     276
#                 ],
#                 [
#                     "2011",
#                     294
#                 ],
#                 [
#                     "2012",
#                     264
#                 ],
#                 [
#                     "2013",
#                     276
#                 ],
#                 [
#                     "2014",
#                     290
#                 ],
#                 [
#                     "2015",
#                     340
#                 ],
#                 [
#                     "2016",
#                     276
#                 ],
#                 [
#                     "2017",
#                     218
#                 ],
#                 [
#                     "2018",
#                     164
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 1434661
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1978",
#                     8.9
#                 ],
#                 [
#                     "1981",
#                     7.4
#                 ],
#                 [
#                     "1982",
#                     7.7
#                 ],
#                 [
#                     "1983",
#                     8.8
#                 ],
#                 [
#                     "1984",
#                     7.88
#                 ],
#                 [
#                     "1985",
#                     7.64
#                 ],
#                 [
#                     "1986",
#                     7.95
#                 ],
#                 [
#                     "1987",
#                     8.11
#                 ],
#                 [
#                     "1988",
#                     8.02
#                 ],
#                 [
#                     "1989",
#                     7.64
#                 ],
#                 [
#                     "1990",
#                     8.32
#                 ],
#                 [
#                     "1991",
#                     7.59
#                 ],
#                 [
#                     "1992",
#                     7.9
#                 ],
#                 [
#                     "1993",
#                     7.79
#                 ],
#                 [
#                     "1994",
#                     8.1

# %%
display_line(df_concat, '总体')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d1ee195449e94ec98aa9777a0cb9250e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d1ee195449e94ec98aa9777a0cb9250e = echarts.init(document.getElementById('d1ee195449e94ec98aa9777a0cb9250e'), 'light', {renderer: 'canvas'});
#
# var option_d1ee195449e94ec98aa9777a0cb9250e = {
#     "title": [
#         {
#             "text": "\u603b\u4f53",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7338433,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     3
#                 ],
#                 [
#                     "1977",
#                     2
#                 ],
#                 [
#                     "1978",
#                     7
#                 ],
#                 [
#                     "1979",
#                     5
#                 ],
#                 [
#                     "1980",
#                     12
#                 ],
#                 [
#                     "1981",
#                     13
#                 ],
#                 [
#                     "1982",
#                     15
#                 ],
#                 [
#                     "1983",
#                     11
#                 ],
#                 [
#                     "1984",
#                     30
#                 ],
#                 [
#                     "1985",
#                     36
#                 ],
#                 [
#                     "1986",
#                     29
#                 ],
#                 [
#                     "1987",
#                     25
#                 ],
#                 [
#                     "1988",
#                     33
#                 ],
#                 [
#                     "1989",
#                     33
#                 ],
#                 [
#                     "1990",
#                     50
#                 ],
#                 [
#                     "1991",
#                     46
#                 ],
#                 [
#                     "1992",
#                     54
#                 ],
#                 [
#                     "1993",
#                     64
#                 ],
#                 [
#                     "1994",
#                     71
#                 ],
#                 [
#                     "1995",
#                     96
#                 ],
#                 [
#                     "1996",
#                     107
#                 ],
#                 [
#                     "1997",
#                     105
#                 ],
#                 [
#                     "1998",
#                     103
#                 ],
#                 [
#                     "1999",
#                     114
#                 ],
#                 [
#                     "2000",
#                     144
#                 ],
#                 [
#                     "2001",
#                     186
#                 ],
#                 [
#                     "2002",
#                     177
#                 ],
#                 [
#                     "2003",
#                     208
#                 ],
#                 [
#                     "2004",
#                     241
#                 ],
#                 [
#                     "2005",
#                     248
#                 ],
#                 [
#                     "2006",
#                     251
#                 ],
#                 [
#                     "2007",
#                     244
#                 ],
#                 [
#                     "2008",
#                     243
#                 ],
#                 [
#                     "2009",
#                     300
#                 ],
#                 [
#                     "2010",
#                     342
#                 ],
#                 [
#                     "2011",
#                     355
#                 ],
#                 [
#                     "2012",
#                     327
#                 ],
#                 [
#                     "2013",
#                     338
#                 ],
#                 [
#                     "2014",
#                     351
#                 ],
#                 [
#                     "2015",
#                     396
#                 ],
#                 [
#                     "2016",
#                     332
#                 ],
#                 [
#                     "2017",
#                     269
#                 ],
#                 [
#                     "2018",
#                     198
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 7338433
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     7.43
#                 ],
#                 [
#                     "1977",
#                     7.45
#                 ],
#                 [
#                     "1978",
#                     7.99
#                 ],
#                 [
#                     "1979",
#                     7.92
#                 ],
#                 [
#                     "1980",
#                     8.36
#                 ],
#                 [
#                     "1981",
#                     7.84
#                 ],
#                 [
#                     "1982",
#                     7.5
#                 ],
#                 [
#                     "1983",
#                     7.79
#                 ],
#                 [
#                     "1984",
#                     7.53
#                 ],
#                 [
#                     "1985",
#                     7.43
#                 ],
#                 [
#                     "1986",

# %% [markdown]
# # 2

# %%
df_concat[df_concat['评价人数/人'] > 50000]
# Out:
#             剧名    年份                           导演  \
# 18      新白娘子传奇  1992                     夏祖辉 / 何麒
# 26     我可能不会爱你  2011                          瞿友宁
# 37       恶作剧之吻  2005                          瞿友宁
# 81        还珠格格  1998                          孙树培
# 95        流星花园  2001                          蔡岳勋
# 120      倚天屠龙记  2003                     杨韬 / 赖水清
# 225    还珠格格第二部  1999                     李平 / 孙树培
# 351     情深深雨__  2001                           李平
# 746       神雕侠侣  1995                          李添胜
# 755       天龙八部  1997                          李添胜
# 756       金枝欲孽  2004                          戚其义
# 775        鹿鼎记  1998                          李添胜
# 814       潜行狙击  2011                    庄伟建 / 苏万聪
# 846        寻秦记  2001  石铭泉 / 刘顺安 / 林子欣 / 吴锦源 / 文伟鸿
# 896      倚天屠龙记  2003                     杨韬 / 赖水清
# 898       使徒行者  2014                          文伟鸿
# 1779      天盛长歌  2018                     沈严 / 刘海波
# 1785      和平饭店  2018                      李骏 / 白涛
# 1788   香蜜沉沉烬如霜  2018               朱锐斌 / 李秉光 / 澄丰
# 1803       如懿传  2018                           汪俊
# 1838        沙海  2018               毛鲲宇 / 李泽露 / 邹曦
# 1908        扶摇  2018                杨文军 / 谢泽 / 李才
# 1936      甜蜜暴击  2018                          柯翰辰
# 1941      白夜追凶  2017                           王伟
# 1944       白鹿原  2017                           刘进
# 1945    你好，旧时光  2017                           沙漠
# 1947  琅琊榜之风起长林  2017                      孔笙 / 李雪
# 1950     人民的名义  2017                           李路
# 1951        河神  2017                           田里
# 1953      无证之罪  2017                           吕行
# ...        ...   ...                          ...
# 3079     万万没想到  2013                          易小星
# 3106      龙门镖局  2013                           王勇
# 3383    北京爱情故事  2012                          陈思诚
# 3606    后宫·甄_传  2011                          郑晓龙
# 3622      步步惊心  2011                          李国立
# 3628     爱情公寓2  2011                           韦正
# 3649      裸婚时代  2011                          滕华涛
# 3953      美人心计  2010              吴锦源 / 梁欣全 / 陈国华
# 4176        潜伏  2009                      姜伟 / 付玮
# 4204      爱情公寓  2009                           韦正
# 4211        蜗居  2009                          滕华涛
# 4212    仙剑奇侠传三  2009                          李国立
# 4607  大明王朝1566  2007                           张黎
# 4661        奋斗  2007                     赵宝刚 / 王迎
# 4798      武林外传  2006                           尚敬
# 4800      士兵突击  2006                          康洪雷
# 4979        亮剑  2005                      张前 / 陈健
# 4990     仙剑奇侠传  2005        吴锦源 / 梁胜权 / 麦贯之 / 于建福
# 5338      金粉世家  2003                          李大为
# 5346     倚天屠龙记  2003                     杨韬 / 赖水清
# 5387      粉红女郎  2003                          伍宗德
# 5596       大宅门  2001                          郭宝昌
# 5603      康熙王朝  2001                    陈家林 / 刘大印
# 5669    情深深雨__  2001                           李平
# 5730      大明宫词  2000                          李少红
# 5751     少年包青天  2000                          胡明凯
# 5856   还珠格格第二部  1999                     李平 / 孙树培
# 5895      还珠格格  1998                          孙树培
# 6219       红楼梦  1987                          王扶林
# 6231       西游记  1986                           杨洁
#
#                                                      编剧  \
# 18                      贡敏 / 赵文川 / 方桂兰 / 何冀平 / 夏祖辉 / 何麒
# 26                                                  徐誉庭
# 37                                                  多田薰
# 81                                                   琼瑶
# 95                               柴智屏 / 冯家瑞 / 毛训容 / 神尾叶子
# 120                                        陈兵 / 张敬 / 韦辛
# 225                                                  琼瑶
# 351                                                  琼瑶
# 746                                      黄国辉 / 赵静蓉 / 金庸
# 755                                            金庸 / 梁咏梅
# 756                                                 周旭明
# 775                                            金庸 / 陈静仪
# 814                                           欧冠瑛 / 蔡淑贤
# 846                    黄国辉 / 汤建平 / 刘彩云 / 张小方 / 何群娥 / 黄易
# 896                                        陈兵 / 张敬 / 韦辛
# 898                    叶天成 / 伍立光 / 梁丝钧 / 杨咏莹 / 朱智 / 庞士杰
# 1779                            路怡 / 邹越 / 卢菁 / 王佩 / 邱永懿
# 1785                                                 张莱
# 1788                         马佳 / 徐子善 / 刘格林 / 陈璐莎 / 张鸢盎
# 1803                                                流潋紫
# 1838                                   南派三叔 / 汤祈岑 / 张鸢盎
# 1908                                           解__ / 卢菁
# 1936                                                曹如萍
# 1941                                           指纹 / 顾小白
# 1944                                           申捷 / 陈忠实
# 1945  八月长安 / 卓越泡沫 / 赵_ / 陈潇骁 / 陆洋 / 邓珂 / 潘可唯 / 张紫微 /...
# 1947                                                 海宴
# 1950                                                周梅森
# 1951                                   刘成龙 / 杨宏伟 / 天下霸唱
# 1953                                          马伪八 / 紫金陈
# ...                                                 ...
# 3079                                                至尊玉
# 3106                                                宁财神
# 3383                                          陈思诚 / 李亚玲
# 3606                                          流潋紫 / 王小平
# 3622                                           桐华 / 王莉芝
# 3628                                                 汪远
# 3649                                月影兰析 / 文章 / 周涌 / 温蓉
# 3953                                            于正 / 邹越
# 4176                                      姜伟 / 林黎胜 / 龙一
# 4204                                                 汪远
# 4211                                      六六 / 滕华涛 / 曹盾
# 4212                                                邓紫珊
# 4607                                                刘和平
# 4661                                                 石康
# 4798                                                宁财神
# 4800                                                兰晓龙
# 4979                                           都梁 / 江奇涛
# 4990                                陶海 / 王远 / 阎虹宇 / 阎振华
# 5338                               刘国权 / 韩小汐 / 王军 / 张恨水
# 5346                                       陈兵 / 张敬 / 韦辛
# 5387                                           张琪 / 吴画山
# 5596                                                郭宝昌
# 5603                                    朱苏进 / 胡建新 / 二月河
# 5669                                                 琼瑶
# 5730                                            郑重 / 王要
# 5751                                                黄浩华
# 5856                                                 琼瑶
# 5895                                                 琼瑶
# 6219                                曹雪芹 / 周雷 / 刘耕路 / 周岭
# 6231                               吴承恩 / 戴英禄 / 杨洁 / 邹忆青
#
#                                                      主演  \
# 18         赵雅芝 / 叶童 / 陈美琪 / 石乃文 / 夏光莉 / 乾德门 / 尹宝莲 / 阮虔芷
# 26    林依晨 / 陈柏霖 / 王阳明 / 陈匡怡 / 陆明君 / 黄志玮 / 孟耿如 / 林美秀 ...
# 37              郑元畅 / 林依晨 / 赵咏华 / 唐从圣 / 汪东城 / 许玮甯 / 张永正
# 81    赵薇 / 苏有朋 / 林心如 / 周杰 / 陈志朋 / 范冰冰 / 张铁林 / 戴春荣 / ...
# 95    徐熙媛 / 言承旭 / 周渝民 / 朱孝天 / 吴建豪 / 杨丞琳 / 钱韦杉 / 许玮伦 ...
# 120   苏有朋 / 贾静雯 / 高圆圆 / 张国立 / 张铁林 / 陶虹 / 徐锦江 / 王刚 / ...
# 225   赵薇 / 苏有朋 / 张铁林 / 周杰 / 林心如 / 范冰冰 / 刘丹 / 牟凤彬 / 王...
# 351   赵薇 / 古巨基 / 林心如 / 苏有朋 / 寇振海 / 李钰 / 高鑫 / 王琳 / 徐幸...
# 746   古天乐 / 李若彤 / 李绮虹 / 张可颐 / 雪梨 / 傅明宪 / 张翼 / 陈启泰 / ...
# 755   黄日华 / 陈浩民 / 樊少皇 / 李若彤 / 赵学而 / 刘玉翠 / 刘锦玲 / 张国强 ...
# 756   邓萃雯 / 黎姿 / 张可颐 / 佘诗曼 / 林保怡 / 陈豪 / 梁_ / 陈秀珠 / 陈...
# 775   陈小春 / 马浚伟 / 刘玉翠 / 梁小冰 / 徐濠萦 / 陈少霞 / 邝文_ / 王伟 /...
# 814   黄宗泽 / 谢天华 / 陈法拉 / 徐子珊 / 刘松仁 / 郭政鸿 / 欧阳靖 / 张国强 ...
# 846      古天乐 / 江华 / 宣萱 / 郭羡妮 / 林_ / 滕丽名 / 郑雪儿 / 雪梨 / 郭锋
# 896   苏有朋 / 贾静雯 / 高圆圆 / 张国立 / 张铁林 / 陶虹 / 徐锦江 / 王刚 / ...
# 898   苗侨伟 / 佘诗曼 / 林_ / 沈震轩 / 陈敏之 / 江美仪 / 许绍雄 / 高海宁 /...
# 1779  陈坤 / 倪妮 / 赵立新 / 倪大红 / 袁弘 / 白敬亭 / 张晓晨 / 刘敏涛 / 海...
# 1785  陈数 / 雷佳音 / 李光洁 / 陶慧 / 张一龙 / 陈冠宁 / 阎俊希 / 王_兮 / ...
# 1788  杨紫 / 邓伦 / 陈钰琪 / 罗云熙 / 王一菲 / 邹廷威 / 周海媚 / 萨顶顶 / ...
# 1803  周迅 / 霍建华 / 张钧甯 / 李纯 / 辛芷蕾 / 董洁 / 胡可 / 邬君梅 / 童瑶...
# 1838  吴磊 / 秦昊 / 张萌 / 杨蓉 / 季晨 / 朱杰 / 朱戬 / 王皓轩 / 陈_文 /...
# 1908  杨幂 / 阮经天 / 刘奕君 / 王劲松 / 高伟光 / 赖艺 / 张雅钦 / 胡可 / 高...
# 1936                    鹿晗 / 关晓彤 / 裴子添 / 邵雨薇 / 李萌萌 / 赵越
# 1941  潘粤明 / 王泷正 / 梁缘 / 吕晓霖 / 尹姝贻 / 侯雪龙 / 宋乃刚 / 王余阳 /...
# 1944  张嘉译 / 秦海璐 / 何冰 / 刘佩琦 / 李洪涛 / 雷佳音 / 翟天临 / 李沁 / ...
# 1945  李兰迪 / 张新成 / 周澄奥 / 李牵 / 许梦圆 / 赵健雷 / 汤梦佳 / 曹恩齐 /...
# 1947  黄晓明 / 刘昊然 / 佟丽娅 / 张慧雯 / 梅婷 / 张博 / 郭京飞 / 毕彦君 / ...
# 1950  陆毅 / 柯蓝 / 张丰毅 / 吴刚 / 许亚军 / 张志坚 / 胡静 / 张凯丽 / 高亚...
# 1951  李现 / 张铭恩 / 王紫璇 / 陈芋米 / 苇青 / 唐以诺 / 陈剑 / 杨曙铭 / 梁...
# 1953  秦昊 / 邓家佳 / 姚橹 / 代旭 / 王真儿 / 宁理 / 荆浩 / 林鹏 / 袁满 /...
# ...                                                 ...
# 3079                                白客 / 葛布 / 易小星 / 张本煜
# 3106        郭京飞 / 袁咏仪 / 李倩 / 张瑞涵 / 钱芳 / 刘冠麟 / 杨皓宇 / 傅家缘
# 3383  陈思诚 / 张译 / 李晨 / 杨幂 / 佟丽娅 / 张歆艺 / 莫小棋 / 樊少皇 / 陈...
# 3606  孙俪 / 陈建斌 / 蔡少芬 / 李东学 / 蒋欣 / 陶昕然 / 斓曦 / 孙茜 / 张晓...
# 3622  刘诗诗 / 吴奇隆 / 郑嘉颖 / 袁弘 / 林更新 / 刘松仁 / 刘心悠 / 韩栋 / ...
# 3628        娄艺潇 / 王传君 / 赵文琪 / 孙艺洲 / 邓家佳 / 李佳航 / 陈赫 / 榕榕
# 3649  文章 / 姚笛 / 张凯丽 / 丁嘉丽 / 韩童生 / 艾如 / 刘天佐 / 万茜 / 冯嘉...
# 3953  林心如 / 杨幂 / 王丽坤 / 陈键锋 / 何晟铭 / 冯绍峰 / 胡杏儿 / 严屹宽 /...
# 4176    孙红雷 / 姚晨 / 沈傲君 / 祖锋 / 冯恩鹤 / 吴刚 / 朱杰 / 范雨林 / 王小毅
# 4204         赵霁 / 金世佳 / 娄艺潇 / 陈赫 / 孙艺洲 / 王传君 / 李金铭 / 榕榕
# 4211  海清 / 李念 / 郝平 / 文章 / 张嘉译 / 邬君梅 / 冯嘉怡 / 吴玉芳 / 宗晓...
# 4212  胡歌 / 霍建华 / 杨幂 / 唐嫣 / 刘诗诗 / 林子聪 / 黄志玮 / 郭晓婷 / 袁...
# 4607  陈宝国 / 黄志忠 / 倪大红 / 王庆祥 / 郭东文 / 郑玉 / 张子健 / 闫妮 / ...
# 4661  马伊_ / 佟大为 / 文章 / 李小璐 / 朱雨辰 / 王珞丹 / 徐梵溪 / 周晓鸥 /...
# 4798      闫妮 / 姚晨 / 沙溢 / 喻恩泰 / 姜超 / 倪虹洁 / 王莎莎 / 范明 / 肖剑
# 4800    王宝强 / 陈思诚 / 段奕宏 / 张译 / 邢佳栋 / 张国强 / 李晨 / 范雷 / 高峰
# 4979  李幼斌 / 何政军 / 张光北 / 童蕾 / 孙俪 / 战卫华 / 陆彭 / 张桐 / 由力...
# 4990  胡歌 / 刘亦菲 / 安以轩 / 刘品言 / 彭于晏 / 谢君豪 / 李丽珍 / 徐锦江 /...
# 5338  陈坤 / 董洁 / 刘亦菲 / 寇振海 / 乔振宇 / 舒耀_ / 吴竞 / 潘星谊 / 朱...
# 5346  苏有朋 / 贾静雯 / 高圆圆 / 张国立 / 张铁林 / 陶虹 / 徐锦江 / 王刚 / ...
# 5387            刘若英 / 张延 / 陈好 / 陆毅 / 胡兵 / 张世 / 陈坤 / 薛佳凝
# 5596  斯琴高娃 / 刘佩琦 / 陈宝国 / 蒋雯丽 / 张丰毅 / 贾妮 / 张艺谋 / 何赛飞 ...
# 5603  斯琴高娃 / 陈道明 / 高兰村 / 茹萍 / 李建群 / 朱晏 / 薛中锐 / 李楠 / ...
# 5669  赵薇 / 古巨基 / 林心如 / 苏有朋 / 寇振海 / 李钰 / 高鑫 / 王琳 / 徐幸...
# 5730  陈红 / 归亚蕾 / 周迅 / 赵文_ / 傅彪 / 申军谊 / 贾妮 / 刘栋 / 吴军忱...
# 5751  周杰 / 释小龙 / 任泉 / 李冰冰 / 陈道明 / 刘怡君 / 刘晓虎 / 郑佩佩 / ...
# 5856  赵薇 / 苏有朋 / 张铁林 / 周杰 / 林心如 / 范冰冰 / 刘丹 / 牟凤彬 / 王...
# 5895  赵薇 / 苏有朋 / 林心如 / 周杰 / 陈志朋 / 范冰冰 / 张铁林 / 戴春荣 / ...
# 6219  欧阳奋强 / 陈晓旭 / 邓婕 / 张莉 / 李婷 / 袁玫 / 张蕾 / 郭霄珍 / 周贤...
# 6231  六小龄童 / 迟重瑞 / 马德华 / 汪粤 / 徐少华 / 闫怀礼 / 朱龙广 / 左大玢 ...
#
#                           类型         制片国家/地区  集数 单集片长/分钟  豆瓣评分  评价人数/人
# 18              爱情 / 奇幻 / 古装              台湾  50      49   9.0   90386
# 26                        爱情              台湾  13      90   8.9  144795
# 37                   喜剧 / 爱情              台湾  20      45   8.8   70545
# 81    剧情 / 喜剧 / 动作 / 爱情 / 古装       台湾 / 中国大陆  24      45   8.3   94996
# 95              剧情 / 喜剧 / 爱情              台湾  20      45   8.2   59663
# 120                  武侠 / 古装  台湾 / 中国大陆 / 香港  40      48   8.1   52009
# 225   剧情 / 喜剧 / 动作 / 爱情 / 古装       台湾 / 中国大陆  48      48   7.6   58502
# 351        剧情 / 爱情 / 音乐 / 战争       中国大陆 / 台湾  46      40   7.1   65189
# 746             爱情 / 武侠 / 古装              香港  32      45   9.0   90149
# 755             剧情 / 武侠 / 古装              香港  45      45   8.8   74952
# 756                       剧情              香港  30      45   8.8   73495
# 775   剧情 / 喜剧 / 动作 / 历史 / 冒险              香港  45      45   8.7   68456
# 814             剧情 / 动作 / 爱情              香港  30      45   8.4   53510
# 846             剧情 / 喜剧 / 历史              香港  40      45   8.3   60854
# 896                  武侠 / 古装  台湾 / 中国大陆 / 香港  40      48   8.1   52005
# 898             剧情 / 爱情 / 犯罪              香港  31      45   8.1   54745
# 1779            剧情 / 爱情 / 古装            中国大陆  56      45   8.3  113356
# 1785                 剧情 / 悬疑            中国大陆  42      45   7.9   51470
# 1788       剧情 / 爱情 / 奇幻 / 古装            中国大陆  63      45   7.7  170197
# 1803            剧情 / 历史 / 古装            中国大陆  87      45   7.4  142905
# 1838                      剧情            中国大陆  52      45   6.5   55454
# 1908            剧情 / 爱情 / 古装            中国大陆  66      45   4.7   66622
# 1936                 喜剧 / 爱情            中国大陆  37      45   2.8   59320
# 1941            剧情 / 悬疑 / 犯罪            中国大陆  32      45   9.0  245310
# 1944                 剧情 / 历史            中国大陆  77      45   8.8   60758
# 1945                 剧情 / 爱情            中国大陆  30      45   8.7   80877
# 1947                 剧情 / 古装            中国大陆  50      45   8.5   87534
# 1950            剧情 / 悬疑 / 犯罪            中国大陆  52      55   8.3  207490
# 1951                 剧情 / 悬疑            中国大陆  24      40   8.2   96313
# 1953                 悬疑 / 犯罪            中国大陆  12      55   8.2   70086
# ...                      ...             ...  ..     ...   ...     ...
# 3079            剧情 / 喜剧 / 短片            中国大陆  15       5   8.2   51840
# 3106                 喜剧 / 古装            中国大陆  40      45   7.4   53414
# 3383                 剧情 / 爱情            中国大陆  39      45   7.5   75422
# 3606                 剧情 / 古装            中国大陆  76      45   9.0  170821
# 3622                 剧情 / 爱情            中国大陆  35      49   8.1  110280
# 3628                 喜剧 / 爱情            中国大陆  20      50   8.0   76083
# 3649            剧情 / 爱情 / 家庭            中国大陆  30      40   7.7   50548
# 3953            剧情 / 爱情 / 古装            中国大陆  40      40   7.6   53736
# 4176                 剧情 / 爱情            中国大陆  30      40   9.2   86352
# 4204                 喜剧 / 爱情            中国大陆  20      45   8.0   98792
# 4211            剧情 / 爱情 / 家庭            中国大陆  35      40   7.9   64996
# 4212       爱情 / 奇幻 / 武侠 / 古装            中国大陆  37      45   7.9   67879
# 4607                 剧情 / 历史            中国大陆  46      42   9.7   55498
# 4661                 喜剧 / 爱情            中国大陆  32      45   7.6   89770
# 4798            喜剧 / 武侠 / 古装            中国大陆  80      40   9.4  157878
# 4800                      剧情            中国大陆  30      45   9.2   74927
# 4979                 剧情 / 战争            中国大陆  30      42   9.1   62633
# 4990       爱情 / 奇幻 / 武侠 / 古装            中国大陆  34      46   8.6   83748
# 5338                 爱情 / 家庭            中国大陆  40      45   8.3   70363
# 5346                 武侠 / 古装  台湾 / 中国大陆 / 香港  40      48   8.1   51948
# 5387            剧情 / 喜剧 / 爱情            中国大陆  39      46   7.5   51829
# 5596  剧情 / 爱情 / 家庭 / 传记 / 历史            中国大陆  40      45   9.3   65727
# 5603       剧情 / 爱情 / 传记 / 历史            中国大陆  46      45   9.0   66851
# 5669       剧情 / 爱情 / 音乐 / 战争       中国大陆 / 台湾  46      40   7.1   65204
# 5730                 剧情 / 爱情            中国大陆  40      47   9.0   64895
# 5751            剧情 / 悬疑 / 古装            中国大陆  40      45   8.1   66366
# 5856  剧情 / 喜剧 / 动作 / 爱情 / 古装       台湾 / 中国大陆  48      48   7.6   58509
# 5895  剧情 / 喜剧 / 动作 / 爱情 / 古装       台湾 / 中国大陆  24      45   8.3   94931
# 6219            剧情 / 爱情 / 古装            中国大陆  36      45   9.6   77398
# 6231  剧情 / 动作 / 奇幻 / 冒险 / 古装            中国大陆  25      45   9.5  103662
#
# [88 rows x 11 columns]

# %%
tmp[tmp['评价人数/人'] > 100000].sort_values(by = '豆瓣评分', ascending = True).head(3)
# Out:
#           剧名    年份                     导演              编剧  \
# 2154    深夜食堂  2017              蔡岳勋 / 胡涵清             陈怡方
# 2155  漂亮的李慧珍  2017                    赵晨阳        卢至柔 / 杨青
# 2321     青云志  2016  朱锐斌 / 周远舟 / 刘国辉 / 朱少杰  邵潇逸 / 张少微 / 张戬
#
#                                                      主演            类型 制片国家/地区  \
# 2154  黄磊 / 赵又廷 / 张钧甯 / 海清 / 何炅 / 陈意涵 / 马苏 / 刘昊然 / 萧敬...            剧情    中国大陆
# 2155  迪丽热巴 / 盛一伦 / 李溪芮 / 张彬彬 / 王骁 / 王一楠 / 任伟 / 王一菲 /...       喜剧 / 爱情    中国大陆
# 2321  李易峰 / 赵丽颖 / 杨紫 / 舒畅 / 王源 / 王俊凯 / 易烊千玺 / 熊乃瑾 / ...  奇幻 / 武侠 / 古装    中国大陆
#
#       集数 单集片长/分钟  豆瓣评分  评价人数/人
# 2154  36      45   2.8  104240
# 2155  40      43   2.8  109354
# 2321  55      45   5.3  122359

# %%
tmp[tmp['评价人数/人'] > 100000].sort_values(by = '豆瓣评分', ascending = False).head(3)
# Out:
#         剧名    年份       导演        编剧  \
# 2436   琅琊榜  2015  孔笙 / 李雪        海宴
# 1941  白夜追凶  2017       王伟  指纹 / 顾小白
# 2444   伪装者  2015       李雪        张勇
#
#                                                      主演            类型 制片国家/地区  \
# 2436  胡歌 / 刘涛 / 王凯 / 陈龙 / 黄维德 / 靳东 / 高鑫 / 张_琰 / 张龄心 ...       剧情 / 古装    中国大陆
# 1941  潘粤明 / 王泷正 / 梁缘 / 吕晓霖 / 尹姝贻 / 侯雪龙 / 宋乃刚 / 王余阳 /...  剧情 / 悬疑 / 犯罪    中国大陆
# 2444  胡歌 / 靳东 / 刘敏涛 / 王凯 / 宋轶 / 王乐君 / 王鸥 / 刘奕君 / 岳_ ...       剧情 / 悬疑    中国大陆
#
#       集数 单集片长/分钟  豆瓣评分  评价人数/人
# 2436  54      45   9.2  256604
# 1941  32      45   9.0  245310
# 2444  48      40   8.4  100309

# %% [markdown]
# # 3

# %%
def style_quantity(df):
    styles = []
    for i in df['类型']:
        style = i.split(' / ')
        for j in style:
            if j != '':
                styles.append(j)
    tmp = pd.DataFrame({'styles': styles})['styles'].value_counts()
    results = pd.DataFrame({'类型': tmp.index, '总部数': tmp.values})
    results.drop(0, inplace = True)
    return results

# %%
def display_bar(df, area):
    x = style_quantity(df)['类型'][:10]
    y = style_quantity(df)['总部数'][:10]
    bar = Bar(area)
    bar.add('总部数', x, y, is_label_show = True, xaxis_interval = 0)
    return bar

# %%
display_bar(df_tw, '台湾')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4bb47bbd877e49248ac343b05c827eab" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4bb47bbd877e49248ac343b05c827eab = echarts.init(document.getElementById('4bb47bbd877e49248ac343b05c827eab'), 'light', {renderer: 'canvas'});
#
# var option_4bb47bbd877e49248ac343b05c827eab = {
#     "title": [
#         {
#             "text": "\u53f0\u6e7e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1160977,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u90e8\u6570",
#             "data": [
#                 337.0,
#                 99.0,
#                 94.0,
#                 90.0,
#                 45.0,
#                 36.0,
#                 34.0,
#                 20.0,
#                 18.0,
#                 16.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1160977
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u90e8\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7231\u60c5",
#                 "\u53e4\u88c5",
#                 "\u559c\u5267",
#                 "\u6b66\u4fa0",
#                 "\u5947\u5e7b",
#                 "\u52a8\u4f5c",
#                 "\u5bb6\u5ead",
#                 "\u5386\u53f2",
#                 "\u540c\u6027",
#                 "\u60ac\u7591"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_4bb47bbd877e49248ac343b05c827eab.setOption(option_4bb47bbd877e49248ac343b05c827eab);
#
#     });
# </script>

# %%
display_bar(df_hk, '香港')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b020806665c7409785d8cf2373918a6f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b020806665c7409785d8cf2373918a6f = echarts.init(document.getElementById('b020806665c7409785d8cf2373918a6f'), 'light', {renderer: 'canvas'});
#
# var option_b020806665c7409785d8cf2373918a6f = {
#     "title": [
#         {
#             "text": "\u9999\u6e2f",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1582906,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u90e8\u6570",
#             "data": [
#                 263.0,
#                 188.0,
#                 164.0,
#                 100.0,
#                 90.0,
#                 89.0,
#                 70.0,
#                 59.0,
#                 42.0,
#                 39.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1582906
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u90e8\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7231\u60c5",
#                 "\u559c\u5267",
#                 "\u53e4\u88c5",
#                 "\u6b66\u4fa0",
#                 "\u72af\u7f6a",
#                 "\u52a8\u4f5c",
#                 "\u60ac\u7591",
#                 "\u5bb6\u5ead",
#                 "\u5386\u53f2",
#                 "\u5947\u5e7b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_b020806665c7409785d8cf2373918a6f.setOption(option_b020806665c7409785d8cf2373918a6f);
#
#     });
# </script>

# %%
display_bar(df_ml, '大陆')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="d1747f95c0a247ea83afe16df42face1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_d1747f95c0a247ea83afe16df42face1 = echarts.init(document.getElementById('d1747f95c0a247ea83afe16df42face1'), 'light', {renderer: 'canvas'});
#
# var option_d1747f95c0a247ea83afe16df42face1 = {
#     "title": [
#         {
#             "text": "\u5927\u9646",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5100380,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u90e8\u6570",
#             "data": [
#                 1143.0,
#                 609.0,
#                 567.0,
#                 479.0,
#                 382.0,
#                 317.0,
#                 289.0,
#                 183.0,
#                 171.0,
#                 169.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5100380
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u90e8\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7231\u60c5",
#                 "\u53e4\u88c5",
#                 "\u559c\u5267",
#                 "\u5bb6\u5ead",
#                 "\u6218\u4e89",
#                 "\u5386\u53f2",
#                 "\u60ac\u7591",
#                 "\u72af\u7f6a",
#                 "\u5947\u5e7b",
#                 "\u52a8\u4f5c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_d1747f95c0a247ea83afe16df42face1.setOption(option_d1747f95c0a247ea83afe16df42face1);
#
#     });
# </script>

# %%
name = style_quantity(df_concat)['类型']
value = style_quantity(df_concat)['总部数']
wordcloud = WordCloud('总体')
wordcloud.add('', name, value, shape = 'circle', word_size_range = [20, 100])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="4fd06db796524b6d9ef479d48fbfc27c" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_4fd06db796524b6d9ef479d48fbfc27c = echarts.init(document.getElementById('4fd06db796524b6d9ef479d48fbfc27c'), 'light', {renderer: 'canvas'});
#
# var option_4fd06db796524b6d9ef479d48fbfc27c = {
#     "title": [
#         {
#             "text": "\u603b\u4f53",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8932967,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 1717,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(114,42,47)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53e4\u88c5",
#                     "value": 861,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(65,3,140)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u5267",
#                     "value": 842,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(10,20,28)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5bb6\u5ead",
#                     "value": 570,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,69,93)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6218\u4e89",
#                     "value": 393,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(150,25,97)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60ac\u7591",
#                     "value": 374,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,136,60)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5386\u53f2",
#                     "value": 373,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,154,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u4fa0",
#                     "value": 324,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(98,29,53)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u4f5c",
#                     "value": 290,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(57,78,23)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72af\u7f6a",
#                     "value": 276,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(35,112,146)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 251,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(8,144,103)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f20\u8bb0",
#                     "value": 123,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(126,109,3)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(9,103,77)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u513f\u7ae5",
#                     "value": 65,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(25,33,110)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u5e7b",
#                     "value": 62,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(71,77,119)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u77ed\u7247",
#                     "value": 55,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,89,15)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5192\u9669",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(135,97,85)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6050\u6016",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(140,31,68)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u540c\u6027",
#                     "value": 25,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(113,103,114)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd0\u52a8",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(12,117,4)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u9b3c\u602a",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(2,73,28)"

# %% [markdown]
# # 4

# %%
def actor_score_number(df):
    actors = []
    scores = []
    for i in df.index:
        tmp = (df['主演'][i].split(' / '), df['豆瓣评分'][i])
        for actor in tmp[0]:
            if actor != '':
                actors.append(actor)
                scores.append(tmp[1])
    datas = pd.DataFrame({'actors': actors, 'scores': scores})
    actors = datas.actors.drop_duplicates()
    my1 = []
    my2 = []
    my3 = []
    for actor in actors:
        my1.append(actor)
        tmp = datas[datas.actors == actor]
        my2.append(round(tmp.scores.sum() / len(tmp), 2))
        my3.append(len(tmp))
    results = pd.DataFrame({'演员': my1, '平均分': my2, '部数': my3}).sort_values('平均分', ascending = False)
    return results

# %%
# actor_score_number(df_concat).to_csv('dataset/演员-平均分-部数.csv', index = False, encoding = 'gbk')

# %%
df = pd.read_csv(open('dataset/演员-平均分-部数.csv',encoding = 'gbk'))

# %%
wb90s = pd.DataFrame({'演员': [item[0] for item in weibo90s().items()], '粉丝数': [item[1] for item in weibo90s().items()]})
wbfans30 = pd.DataFrame({'演员': [item[0] for item in weibofans30().items()], '粉丝数': [item[1] for item in weibofans30().items()]})
wb90s = pd.merge(wb90s, df)
wbfans30 = pd.merge(wbfans30, df)

# %%
def display_overlap(df, name):
    x = df['演员']
    y1 = df['部数']
    y2 = df['平均分']
    bar = Bar(name, '注：横坐标依据粉丝数从大到小排列')
    line = Line()
    bar.add('部数', x, y1, mark_line = ['average'], xaxis_interval = 0, is_datazoom_show = True, datazoom_range = [0, 50])
    line.add('平均分', x, y2, is_label_show = True, mark_line = ['average'])
    overlap = Overlap()
    overlap.add(bar)
    overlap.add(line)
    return overlap

# %%
display_overlap(wb90s, '微博九零后')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="0933e4366f9e44128a7e89adc14e7f03" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_0933e4366f9e44128a7e89adc14e7f03 = echarts.init(document.getElementById('0933e4366f9e44128a7e89adc14e7f03'), 'light', {renderer: 'canvas'});
#
# var option_0933e4366f9e44128a7e89adc14e7f03 = {
#     "title": [
#         {
#             "text": "\u5fae\u535a\u4e5d\u96f6\u540e",
#             "subtext": "\u6ce8\uff1a\u6a2a\u5750\u6807\u4f9d\u636e\u7c89\u4e1d\u6570\u4ece\u5927\u5230\u5c0f\u6392\u5217",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5143843,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u90e8\u6570",
#             "data": [
#                 2.0,
#                 14.0,
#                 20.0,
#                 25.0,
#                 2.0,
#                 16.0,
#                 19.0,
#                 4.0,
#                 9.0,
#                 4.0,
#                 5.0,
#                 25.0,
#                 4.0,
#                 16.0,
#                 9.0,
#                 8.0,
#                 5.0,
#                 17.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5143843
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u9e7f\u6657",
#                     3.5
#                 ],
#                 [
#                     "\u8fea\u4e3d\u70ed\u5df4",
#                     5.02
#                 ],
#                 [
#                     "\u6768\u6d0b",
#                     5.6
#                 ],
#                 [
#                     "\u6768\u7d2b",
#                     6.78
#                 ],
#                 [
#                     "\u9ec4\u5b50\u97ec",
#                     3.35
#                 ],
#                 [
#                     "\u5434\u78ca",
#                     6.15
#                 ],
#                 [
#                     "\u5f20\u4e00\u5c71",
#                     6.89
#                 ],
#                 [
#                     "\u9648\u5b66\u51ac",
#                     3.85
#                 ],
#                 [
#                     "\u9093\u4f26",
#                     6.3
#                 ],
#                 [
#                     "\u5468\u51ac\u96e8",
#                     4.75
#                 ],
#                 [
#                     "\u5218\u660a\u7136",
#                     6.8
#                 ],
#                 [
#                     "\u5173\u6653\u5f64",
#                     6.14
#                 ],
#                 [
#                     "\u767d\u656c\u4ead",
#                     6.72
#                 ],
#                 [
#                     "\u674e\u6c81",
#                     5.97
#                 ],
#                 [
#                     "\u848b\u52b2\u592b",
#                     5.38
#                 ],
#                 [
#                     "\u53e4\u529b\u5a1c\u624e",
#                     4.56
#                 ],
#                 [
#                     "\u5f20\u5929\u7231",
#                     5.18
#                 ],
#                 [
#                     "\u8c2d\u677e\u97f5",
#                     6.4
#                 ],
#                 [
#                     "\u6b27\u9633\u5a1c\u5a1c",
#                     2.6
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5143843,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u90e8\u6570",
#                 "\u5e73\u5747\u5206"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u9e7f\u6657",
#                 "\u8fea\u4e3d\u70ed\u5df4",
#                 "\u6768\u6d0b",
#                 "\u6768\u7d2b",
#                 "\u9ec4\u5b50\u97ec",
#                 "\u5434\u78ca",
#                 "\u5f20\u4e00\u5c71",
#                 "\u9648\u5b66\u51ac",
#                 "\u9093\u4f26",

# %%
display_overlap(wbfans30, '微博粉丝榜')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2b160e14b9914583a0558a3d8d5fe412" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2b160e14b9914583a0558a3d8d5fe412 = echarts.init(document.getElementById('2b160e14b9914583a0558a3d8d5fe412'), 'light', {renderer: 'canvas'});
#
# var option_2b160e14b9914583a0558a3d8d5fe412 = {
#     "title": [
#         {
#             "text": "\u5fae\u535a\u7c89\u4e1d\u699c",
#             "subtext": "\u6ce8\uff1a\u6a2a\u5750\u6807\u4f9d\u636e\u7c89\u4e1d\u6570\u4ece\u5927\u5230\u5c0f\u6392\u5217",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5524716,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u90e8\u6570",
#             "data": [
#                 14.0,
#                 5.0,
#                 37.0,
#                 4.0,
#                 22.0,
#                 17.0,
#                 11.0,
#                 51.0,
#                 25.0,
#                 21.0,
#                 17.0,
#                 15.0,
#                 22.0,
#                 33.0,
#                 30.0,
#                 24.0,
#                 40.0,
#                 11.0,
#                 28.0,
#                 12.0,
#                 27.0,
#                 2.0,
#                 36.0,
#                 2.0,
#                 20.0,
#                 14.0,
#                 18.0,
#                 17.0,
#                 6.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5524716
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u8c22\u5a1c",
#                     6.19
#                 ],
#                 [
#                     "\u4f55\u7085",
#                     5.72
#                 ],
#                 [
#                     "\u6768\u5e42",
#                     6.2
#                 ],
#                 [
#                     "\u6768\u9896",
#                     4.03
#                 ],
#                 [
#                     "\u9648\u5764",
#                     7.42
#                 ],
#                 [
#                     "\u8d75\u8587",
#                     7.16
#                 ],
#                 [
#                     "\u59da\u6668",
#                     8.13
#                 ],
#                 [
#                     "\u6797\u5fc3\u5982",
#                     6.67
#                 ],
#                 [
#                     "\u8d75\u4e3d\u9896",
#                     5.92
#                 ],
#                 [
#                     "\u9093\u8d85",
#                     7.16
#                 ],
#                 [
#                     "\u6797\u5fd7\u9896",
#                     6.55
#                 ],
#                 [
#                     "\u90ed\u5fb7\u7eb2",
#                     6.64
#                 ],
#                 [
#                     "\u9648\u4e54\u6069",
#                     5.8
#                 ],
#                 [
#                     "\u5510\u5ae3",
#                     5.8
#                 ],
#                 [
#                     "\u8d3e\u4e43\u4eae",
#                     6.13
#                 ],
#                 [
#                     "\u80e1\u6b4c",
#                     7.33
#                 ],
#                 [
#                     "\u8303\u51b0\u51b0",
#                     6.74
#                 ],
#                 [
#                     "\u7f57\u5fd7\u7965",
#                     6.5
#                 ],
#                 [
#                     "\u9ec4\u6653\u660e",
#                     6.29
#                 ],
#                 [
#                     "\u9648\u8d6b",
#                     6.04
#                 ],
#                 [
#                     "\u6587\u7ae0",
#                     6.84
#                 ],
#                 [
#                     "\u9e7f\u6657",
#                     3.5
#                 ],
#                 [
#                     "\u674e\u6668",
#                     7.17
#                 ],
#                 [
#                     "\u97e9\u5e9a",
#                     6.5
#                 ],
#                 [
#                     "\u5218\u70e8",
#                     6.65
#                 ],
#                 [
#                     "\u8fea\u4e3d\u70ed\u5df4",
#                     5.02
#                 ],
#                 [
#                     "\u674e\u6613\u5cf0",
#                     6.22
#                 ],
#                 [
#                     "\u9ad8\u5706\u5706",
#                     7.36
#                 ],
#                 [
#                     "\u6797\u66f4\u65b0",
#                     6.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5524716,
#             "xAxisIndex": 0,
#             "yAxisIndex": 0
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u90e8\u6570",
#                 "\u5e73\u5747\u5206"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {

# %% [markdown]
# # 5

# %%
def actor_number(df):
    actors = []
    for i in df['主演']:
        tmp = i.split(' / ')
        for actor in tmp:
            if actor != '':
                actors.append(actor)
    datas = pd.DataFrame({'actors': actors})
    results = pd.DataFrame({'演员': datas.actors.value_counts().index, '部数': datas.actors.value_counts().values})
    return results

# %%
def find_nodes(df):
    tmp = actor_number(df)
    nodes = []
    for i in tmp.index:
        dic = {}
        dic['name'] = tmp['演员'][i]
        dic['value'] = tmp['部数'][i]
        dic['symbolSize'] = tmp['部数'][i]*2
        nodes.append(dic)
    return nodes

# %%
nodes_tw = find_nodes(df_tw)

# %%
nodes_hk = find_nodes(df_hk)

# %%
pd.DataFrame(nodes_hk)
# Out:
#         name  symbolSize  value
# 0        黎耀祥         114     57
# 1        郭晋安          98     49
# 2       欧阳震华          98     49
# 3        马国明          98     49
# 4         刘江          92     46
# 5        邵美琪          88     44
# 6         宣萱          88     44
# 7         杨怡          88     44
# 8        张国强          82     41
# 9         陈豪          82     41
# 10        米雪          80     40
# 11       刘松仁          78     39
# 12       麦长青          76     38
# 13       佘诗曼          76     38
# 14       黄宗泽          76     38
# 15       胡定欣          74     37
# 16       陈荣峻          72     36
# 17       林保怡          72     36
# 18       关礼杰          70     35
# 19       滕丽名          70     35
# 20       蔡少芬          68     34
# 21       胡杏儿          68     34
# 22       许绍雄          68     34
# 23       陶大宇          66     33
# 24        秦沛          66     33
# 25       吴卓羲          66     33
# 26       罗乐林          64     32
# 27        秦煌          64     32
# 28       马德钟          64     32
# 29       汪明荃          62     31
# ...      ...         ...    ...
# 2618     谢安琪           2      1
# 2619     _毅_           2      1
# 2620      任泉           2      1
# 2621     陈美玲           2      1
# 2622     李静怡           2      1
# 2623     杨得时           2      1
# 2624     何润东           2      1
# 2625     谢 贤           2      1
# 2626     梁梓豪           2      1
# 2627     唐贝诗           2      1
# 2628     田启文           2      1
# 2629      石_           2      1
# 2630     王靖怡           2      1
# 2631     周耀杰           2      1
# 2632     林伟图           2      1
# 2633     吴茜薇           2      1
# 2634     金来群           2      1
# 2635     汤钧禧           2      1
# 2636     罗立勤           2      1
# 2637     申珉熙           2      1
# 2638     袁弥明           2      1
# 2639     李耀景           2      1
# 2640     罗敏玲           2      1
# 2641     于小伟           2      1
# 2642     李满信           2      1
# 2643     刘家荣           2      1
# 2644     黄偌仪           2      1
# 2645     岳跃利           2      1
# 2646  卡·亚历山大           2      1
# 2647     陈佩思           2      1
#
# [2648 rows x 3 columns]

# %%
def actor_list(df):
    results = []
    for actors in df['主演']:
        if actors != '':
            results.append(actors.split(' / '))
    return results

# %%
def find_df1(df):
    tmp = actor_list(df)
    source = []
    target = []
    for actors in tmp:
        for i in actors:
            for j in actors:
                if i != j:
                    source.append(i)
                    target.append(j)
    results = pd.DataFrame({'source': source, 'target': target})
    return results

# %%
def find_df2(df):
    data = find_df1(df)
    results = data[data.duplicated()].drop_duplicates()
    value = []
    for index, row in results.iterrows():
        tmp = data[(data.source == row.source) & (data.target == row.target)]
        value.append(len(tmp))
    results['value'] = value
    return results

# %%
find_df2(df_tw).to_csv('dataset/graph_tw.csv', index = False, encoding = 'gbk')

# %%
# find_df2(df_hk).to_csv('dataset/graph_hk.csv', index = False, encoding = 'gbk')

# %%
graph_tw = pd.read_csv('dataset/graph_tw.csv', encoding = 'gbk')

# %%
links_tw = []
for index, row in graph_tw.iterrows():
    source = row.source
    target = row.target
    links_tw.append({'source': source, 'target': target})

# %%
def display_graph(nodes, links):
    graph = Graph('台湾地区演员关系图')
    graph.add('', nodes, links)
    return graph

# %%
display_graph(nodes_tw, links_tw).render('台湾地区演员关系图.html')

# %%
graph_hk = pd.read_csv('dataset/graph_tw.csv', encoding = 'gbk')

links_hk = []
for index, row in graph_hk.iterrows():
    source = row.source
    target = row.target
    links_hk.append({'source': source, 'target': target})
    
def display_graph_hk(nodes, links):
    graph = Graph('香港地区演员关系图')
    graph.add('', nodes, links)
    return graph

display_graph_hk(nodes_hk, links_hk).render('香港地区演员关系图.html')

# %% [markdown]
# # 6

# %%
datas = pd.read_csv('dataset/tmp.csv', encoding = 'gbk')
results = pd.DataFrame(index = datas['年份'].drop_duplicates().sort_values())

# %%
def add_column(area):
    column = []
    for year in results.index:
        column.append(len(datas[(datas['年份'] == year) & (datas['制片国家/地区'] == area)]))
    results[area] = column

# %%
areas = ['香港 / 台湾', '中国大陆 / 香港', '中国大陆 / 台湾', '中国大陆 / 香港 / 台湾']
for area in areas:
    add_column(area)

# %%
results
# Out:
#       香港 / 台湾  中国大陆 / 香港  中国大陆 / 台湾  中国大陆 / 香港 / 台湾
# 年份
# 1986        0          2          0               0
# 1990        0          1          0               0
# 1991        0          0          1               0
# 1993        1          1          0               1
# 1994        0          0          0               1
# 1995        1          1          2               0
# 1996        1          4          1               2
# 1997        0          3          0               0
# 1998        1          2          5               1
# 1999        0          2          6               0
# 2000        2          2          3               1
# 2001        2          2          3               0
# 2002        1          3          1               0
# 2003        1          1          4               2
# 2004        1          1          1               1
# 2005        1          5          4               1
# 2006        0          3          4               0
# 2007        0          3          7               0
# 2008        0          4          1               0
# 2009        0          0          3               1
# 2010        0          1          3               0
# 2011        0          2          6               0
# 2012        0          2          1               0
# 2013        0          1          1               0
# 2014        1          1          2               0
# 2015        0          1          2               0
# 2016        0          1          3               0
# 2017        0          3          0               0
# 2018        0          6          1               0

# %%
es = EffectScatter('三地合作情况图', '注：纵坐标代表合作程度，值越大表示合作次数越多')
x = results.index
def add_es(area):
    values = []
    for value in results[area].values:
        if value == 0:
            values.append(None)
        else:
            values.append(value)
    y = values
    es.add(area, x, y, xaxis_min = 1985, xaxis_max = 2020, xaxis_force_interval = 5)

# %%
for area in areas:
    add_es(area)

# %%
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e45055f641f84b5cb9dcaabb6b049400" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e45055f641f84b5cb9dcaabb6b049400 = echarts.init(document.getElementById('e45055f641f84b5cb9dcaabb6b049400'), 'light', {renderer: 'canvas'});
#
# var option_e45055f641f84b5cb9dcaabb6b049400 = {
#     "title": [
#         {
#             "text": "\u4e09\u5730\u5408\u4f5c\u60c5\u51b5\u56fe",
#             "subtext": "\u6ce8\uff1a\u7eb5\u5750\u6807\u4ee3\u8868\u5408\u4f5c\u7a0b\u5ea6\uff0c\u503c\u8d8a\u5927\u8868\u793a\u5408\u4f5c\u6b21\u6570\u8d8a\u591a",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7198027,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u9999\u6e2f / \u53f0\u6e7e",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     1986,
#                     null
#                 ],
#                 [
#                     1990,
#                     null
#                 ],
#                 [
#                     1991,
#                     null
#                 ],
#                 [
#                     1993,
#                     1.0
#                 ],
#                 [
#                     1994,
#                     null
#                 ],
#                 [
#                     1995,
#                     1.0
#                 ],
#                 [
#                     1996,
#                     1.0
#                 ],
#                 [
#                     1997,
#                     null
#                 ],
#                 [
#                     1998,
#                     1.0
#                 ],
#                 [
#                     1999,
#                     null
#                 ],
#                 [
#                     2000,
#                     2.0
#                 ],
#                 [
#                     2001,
#                     2.0
#                 ],
#                 [
#                     2002,
#                     1.0
#                 ],
#                 [
#                     2003,
#                     1.0
#                 ],
#                 [
#                     2004,
#                     1.0
#                 ],
#                 [
#                     2005,
#                     1.0
#                 ],
#                 [
#                     2006,
#                     null
#                 ],
#                 [
#                     2007,
#                     null
#                 ],
#                 [
#                     2008,
#                     null
#                 ],
#                 [
#                     2009,
#                     null
#                 ],
#                 [
#                     2010,
#                     null
#                 ],
#                 [
#                     2011,
#                     null
#                 ],
#                 [
#                     2012,
#                     null
#                 ],
#                 [
#                     2013,
#                     null
#                 ],
#                 [
#                     2014,
#                     1.0
#                 ],
#                 [
#                     2015,
#                     null
#                 ],
#                 [
#                     2016,
#                     null
#                 ],
#                 [
#                     2017,
#                     null
#                 ],
#                 [
#                     2018,
#                     null
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 7198027
#         },
#         {
#             "type": "effectScatter",
#             "name": "\u4e2d\u56fd\u5927\u9646 / \u9999\u6e2f",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     1986,
#                     2.0
#                 ],
#                 [
#                     1990,
#                     1.0
#                 ],
#                 [
#                     1991,
#                     null
#                 ],
#                 [
#                     1993,
#                     1.0
#                 ],
#                 [
#                     1994,
#                     null
#                 ],
#                 [
#                     1995,
#                     1.0
#                 ],
#                 [
#                     1996,
#                     4.0
#                 ],
#                 [
#                     1997,
#                     3.0
#                 ],
#                 [
#                     1998,
#                     2.0
#                 ],
#                 [
#                     1999,
#                     2.0
#                 ],
#                 [
#                     2000,
#                     2.0
#                 ],
#                 [
#                     2001,
#                     2.0
#                 ],
#                 [
#                     2002,
#                     3.0
#                 ],
#                 [
#                     2003,
#                     1.0
#                 ],
#                 [
#                     2004,
#                     1.0
#                 ],
#                 [
#                     2005,
#                     5.0
#                 ],
#                 [
#                     2006,
#                     3.0
#                 ],
#                 [
#                     2007,
#                     3.0
#                 ],
#                 [
#                     2008,
#                     4.0
#                 ],
#                 [
#                     2009,
#                     null
#                 ],
#                 [
#                     2010,
#                     1.0
#                 ],
#                 [
#                     2011,
#                     2.0
#                 ],
#                 [
#                     2012,
#                     2.0
#                 ],
#                 [
#                     2013,
#                     1.0
#                 ],
#                 [
#                     2014,
#                     1.0
#                 ],
#                 [
#                     2015,
#                     1.0
#                 ],
#                 [
#                     2016,
#                     1.0
#                 ],
#                 [
#                     2017,
#                     3.0

# %% [markdown]
# # 7
