# %%
import pandas as pd
from weibo import weibo90s
from weibo import weibofans30
from pyecharts import Bar, Line, Graph, Overlap, WordCloud, EffectScatter
# Out:
# ERROR:lml.utils:failed to import pyecharts_snapshot
# Traceback (most recent call last):
#   File "/Users/linhuiqing/venv/lib/python3.7/site-packages/lml/utils.py", line 43, in do_import
#     plugin_module = __import__(plugin_module_name)
# ModuleNotFoundError: No module named 'pyecharts_snapshot'

# %%
df_tw = pd.read_csv('dataset/results_tw.csv', encoding = 'gbk').fillna('')
df_hk = pd.read_csv('dataset/results_hk.csv', encoding = 'gbk').fillna('')
df_ml = pd.read_csv('dataset/results_ml.csv', encoding = 'gbk').fillna('')

# %%
df_concat = pd.concat([df_tw, df_hk, df_ml], ignore_index = True).drop_duplicates()

# %% [markdown]
# # 1

# %%
def year_quantity(df):
    years = []
    numbers = []
    for i in df['年份'].drop_duplicates().sort_values():
        tmp = df[df['年份'] == i]
        years.append(i)
        numbers.append(len(tmp))
    results = pd.DataFrame({'年份': years, '总部数': numbers})
    return results

# %%
def year_quality(df):
    years = []
    scores = []
    for i in df['年份'].drop_duplicates().sort_values():
        tmp = df[df['年份'] == i]
        score = tmp['豆瓣评分'].sum() / len(tmp)
        years.append(i)
        scores.append(round(score, 2))
    results = pd.DataFrame({'年份': years, '平均分': scores})
    return results

# %%
def display_line(df, area):
    x = df['年份'].drop_duplicates().sort_values().apply(str)
    y1 = year_quantity(df)['总部数']
    y2 = year_quality(df)['平均分']
    line = Line(area)
    line.add('总部数', x, y1, mark_line = ['average'])
    line.add('平均分', x, y2, mark_line = ['average'])
    return line

# %%
display_line(df_tw, '台湾')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="96cb30106d9b4ff180240c903391de88" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_96cb30106d9b4ff180240c903391de88 = echarts.init(document.getElementById('96cb30106d9b4ff180240c903391de88'), 'light', {renderer: 'canvas'});
#
# var option_96cb30106d9b4ff180240c903391de88 = {
#     "title": [
#         {
#             "text": "\u53f0\u6e7e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2799603,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1984",
#                     8
#                 ],
#                 [
#                     "1985",
#                     9
#                 ],
#                 [
#                     "1986",
#                     7
#                 ],
#                 [
#                     "1987",
#                     6
#                 ],
#                 [
#                     "1988",
#                     9
#                 ],
#                 [
#                     "1989",
#                     5
#                 ],
#                 [
#                     "1990",
#                     14
#                 ],
#                 [
#                     "1991",
#                     9
#                 ],
#                 [
#                     "1992",
#                     13
#                 ],
#                 [
#                     "1993",
#                     13
#                 ],
#                 [
#                     "1994",
#                     10
#                 ],
#                 [
#                     "1995",
#                     17
#                 ],
#                 [
#                     "1996",
#                     18
#                 ],
#                 [
#                     "1997",
#                     10
#                 ],
#                 [
#                     "1998",
#                     14
#                 ],
#                 [
#                     "1999",
#                     17
#                 ],
#                 [
#                     "2000",
#                     20
#                 ],
#                 [
#                     "2001",
#                     24
#                 ],
#                 [
#                     "2002",
#                     23
#                 ],
#                 [
#                     "2003",
#                     30
#                 ],
#                 [
#                     "2004",
#                     32
#                 ],
#                 [
#                     "2005",
#                     35
#                 ],
#                 [
#                     "2006",
#                     36
#                 ],
#                 [
#                     "2007",
#                     31
#                 ],
#                 [
#                     "2008",
#                     21
#                 ],
#                 [
#                     "2009",
#                     34
#                 ],
#                 [
#                     "2010",
#                     37
#                 ],
#                 [
#                     "2011",
#                     39
#                 ],
#                 [
#                     "2012",
#                     34
#                 ],
#                 [
#                     "2013",
#                     39
#                 ],
#                 [
#                     "2014",
#                     31
#                 ],
#                 [
#                     "2015",
#                     28
#                 ],
#                 [
#                     "2016",
#                     27
#                 ],
#                 [
#                     "2017",
#                     25
#                 ],
#                 [
#                     "2018",
#                     15
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 2799603
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1984",
#                     7.44
#                 ],
#                 [
#                     "1985",
#                     7.52
#                 ],
#                 [
#                     "1986",
#                     7.57
#                 ],
#                 [
#                     "1987",
#                     7.38
#                 ],
#                 [
#                     "1988",
#                     7.44
#                 ],
#                 [
#                     "1989",
#                     7.38
#                 ],
#                 [
#                     "1990",
#                     7.34
#                 ],
#                 [
#                     "1991",
#                     7.83
#                 ],
#                 [
#                     "1992",
#                     7.86
#                 ],
#                 [
#                     "1993",
#                     7.74
#                 ],
#                 [
#                     "1994",
#                     7.45
#                 ],
#                 [
#                     "1995",
#                     7.33
#                 ],
#                 [
#                     "1996",
#                     7.58
#                 ],
#                 [
#                     "1997",
#                     7.25
#                 ],
#                 [
#                     "1998",
#                     7.35
#                 ],
#                 [
#                     "1999",
#                     6.99
#                 ],
#                 [
#                     "2000",
#                     7.09
#                 ],
#                 [
#                     "2001",
#                     7.07
#                 ],
#                 [
#                     "2002",
#                     6.62

# %%
display_line(df_hk, '香港')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="1b68934b138d42a0b1851423743fec6a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_1b68934b138d42a0b1851423743fec6a = echarts.init(document.getElementById('1b68934b138d42a0b1851423743fec6a'), 'light', {renderer: 'canvas'});
#
# var option_1b68934b138d42a0b1851423743fec6a = {
#     "title": [
#         {
#             "text": "\u9999\u6e2f",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 716586,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     3
#                 ],
#                 [
#                     "1977",
#                     2
#                 ],
#                 [
#                     "1978",
#                     6
#                 ],
#                 [
#                     "1979",
#                     5
#                 ],
#                 [
#                     "1980",
#                     12
#                 ],
#                 [
#                     "1981",
#                     12
#                 ],
#                 [
#                     "1982",
#                     11
#                 ],
#                 [
#                     "1983",
#                     10
#                 ],
#                 [
#                     "1984",
#                     17
#                 ],
#                 [
#                     "1985",
#                     18
#                 ],
#                 [
#                     "1986",
#                     9
#                 ],
#                 [
#                     "1987",
#                     7
#                 ],
#                 [
#                     "1988",
#                     13
#                 ],
#                 [
#                     "1989",
#                     20
#                 ],
#                 [
#                     "1990",
#                     23
#                 ],
#                 [
#                     "1991",
#                     20
#                 ],
#                 [
#                     "1992",
#                     23
#                 ],
#                 [
#                     "1993",
#                     33
#                 ],
#                 [
#                     "1994",
#                     33
#                 ],
#                 [
#                     "1995",
#                     32
#                 ],
#                 [
#                     "1996",
#                     33
#                 ],
#                 [
#                     "1997",
#                     39
#                 ],
#                 [
#                     "1998",
#                     36
#                 ],
#                 [
#                     "1999",
#                     31
#                 ],
#                 [
#                     "2000",
#                     35
#                 ],
#                 [
#                     "2001",
#                     33
#                 ],
#                 [
#                     "2002",
#                     29
#                 ],
#                 [
#                     "2003",
#                     35
#                 ],
#                 [
#                     "2004",
#                     35
#                 ],
#                 [
#                     "2005",
#                     43
#                 ],
#                 [
#                     "2006",
#                     40
#                 ],
#                 [
#                     "2007",
#                     27
#                 ],
#                 [
#                     "2008",
#                     35
#                 ],
#                 [
#                     "2009",
#                     26
#                 ],
#                 [
#                     "2010",
#                     31
#                 ],
#                 [
#                     "2011",
#                     25
#                 ],
#                 [
#                     "2012",
#                     30
#                 ],
#                 [
#                     "2013",
#                     24
#                 ],
#                 [
#                     "2014",
#                     32
#                 ],
#                 [
#                     "2015",
#                     30
#                 ],
#                 [
#                     "2016",
#                     32
#                 ],
#                 [
#                     "2017",
#                     26
#                 ],
#                 [
#                     "2018",
#                     20
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 716586
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     7.43
#                 ],
#                 [
#                     "1977",
#                     7.45
#                 ],
#                 [
#                     "1978",
#                     7.83
#                 ],
#                 [
#                     "1979",
#                     7.92
#                 ],
#                 [
#                     "1980",
#                     8.36
#                 ],
#                 [
#                     "1981",
#                     7.88
#                 ],
#                 [
#                     "1982",
#                     7.43
#                 ],
#                 [
#                     "1983",
#                     7.69
#                 ],
#                 [
#                     "1984",
#                     7.46
#                 ],
#                 [
#                     "1985",
#                     7.27
#                 ],
#                 [
#                     "1986",
#                     7.69
#                 ],

# %%
display_line(df_ml, '大陆')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="4e041db695ff412786ddf035e0660f25" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_4e041db695ff412786ddf035e0660f25 = echarts.init(document.getElementById('4e041db695ff412786ddf035e0660f25'), 'light', {renderer: 'canvas'});
#
# var option_4e041db695ff412786ddf035e0660f25 = {
#     "title": [
#         {
#             "text": "\u5927\u9646",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5791092,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1978",
#                     1
#                 ],
#                 [
#                     "1981",
#                     1
#                 ],
#                 [
#                     "1982",
#                     4
#                 ],
#                 [
#                     "1983",
#                     1
#                 ],
#                 [
#                     "1984",
#                     5
#                 ],
#                 [
#                     "1985",
#                     9
#                 ],
#                 [
#                     "1986",
#                     13
#                 ],
#                 [
#                     "1987",
#                     12
#                 ],
#                 [
#                     "1988",
#                     11
#                 ],
#                 [
#                     "1989",
#                     8
#                 ],
#                 [
#                     "1990",
#                     13
#                 ],
#                 [
#                     "1991",
#                     17
#                 ],
#                 [
#                     "1992",
#                     18
#                 ],
#                 [
#                     "1993",
#                     18
#                 ],
#                 [
#                     "1994",
#                     29
#                 ],
#                 [
#                     "1995",
#                     48
#                 ],
#                 [
#                     "1996",
#                     59
#                 ],
#                 [
#                     "1997",
#                     56
#                 ],
#                 [
#                     "1998",
#                     55
#                 ],
#                 [
#                     "1999",
#                     68
#                 ],
#                 [
#                     "2000",
#                     93
#                 ],
#                 [
#                     "2001",
#                     131
#                 ],
#                 [
#                     "2002",
#                     125
#                 ],
#                 [
#                     "2003",
#                     147
#                 ],
#                 [
#                     "2004",
#                     175
#                 ],
#                 [
#                     "2005",
#                     173
#                 ],
#                 [
#                     "2006",
#                     177
#                 ],
#                 [
#                     "2007",
#                     191
#                 ],
#                 [
#                     "2008",
#                     189
#                 ],
#                 [
#                     "2009",
#                     244
#                 ],
#                 [
#                     "2010",
#                     276
#                 ],
#                 [
#                     "2011",
#                     294
#                 ],
#                 [
#                     "2012",
#                     264
#                 ],
#                 [
#                     "2013",
#                     276
#                 ],
#                 [
#                     "2014",
#                     290
#                 ],
#                 [
#                     "2015",
#                     340
#                 ],
#                 [
#                     "2016",
#                     276
#                 ],
#                 [
#                     "2017",
#                     218
#                 ],
#                 [
#                     "2018",
#                     164
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 5791092
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1978",
#                     8.9
#                 ],
#                 [
#                     "1981",
#                     7.4
#                 ],
#                 [
#                     "1982",
#                     7.7
#                 ],
#                 [
#                     "1983",
#                     8.8
#                 ],
#                 [
#                     "1984",
#                     7.88
#                 ],
#                 [
#                     "1985",
#                     7.64
#                 ],
#                 [
#                     "1986",
#                     7.95
#                 ],
#                 [
#                     "1987",
#                     8.11
#                 ],
#                 [
#                     "1988",
#                     8.02
#                 ],
#                 [
#                     "1989",
#                     7.64
#                 ],
#                 [
#                     "1990",
#                     8.32
#                 ],
#                 [
#                     "1991",
#                     7.59
#                 ],
#                 [
#                     "1992",
#                     7.9
#                 ],
#                 [
#                     "1993",
#                     7.79
#                 ],
#                 [
#                     "1994",
#                     8.1

# %%
display_line(df_concat, '总体')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="ee26c1aa399840d3949b262ed06122ff" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_ee26c1aa399840d3949b262ed06122ff = echarts.init(document.getElementById('ee26c1aa399840d3949b262ed06122ff'), 'light', {renderer: 'canvas'});
#
# var option_ee26c1aa399840d3949b262ed06122ff = {
#     "title": [
#         {
#             "text": "\u603b\u4f53",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3762229,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "line",
#             "name": "\u603b\u90e8\u6570",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     3
#                 ],
#                 [
#                     "1977",
#                     2
#                 ],
#                 [
#                     "1978",
#                     7
#                 ],
#                 [
#                     "1979",
#                     5
#                 ],
#                 [
#                     "1980",
#                     12
#                 ],
#                 [
#                     "1981",
#                     13
#                 ],
#                 [
#                     "1982",
#                     15
#                 ],
#                 [
#                     "1983",
#                     11
#                 ],
#                 [
#                     "1984",
#                     30
#                 ],
#                 [
#                     "1985",
#                     36
#                 ],
#                 [
#                     "1986",
#                     29
#                 ],
#                 [
#                     "1987",
#                     25
#                 ],
#                 [
#                     "1988",
#                     33
#                 ],
#                 [
#                     "1989",
#                     33
#                 ],
#                 [
#                     "1990",
#                     50
#                 ],
#                 [
#                     "1991",
#                     46
#                 ],
#                 [
#                     "1992",
#                     54
#                 ],
#                 [
#                     "1993",
#                     64
#                 ],
#                 [
#                     "1994",
#                     71
#                 ],
#                 [
#                     "1995",
#                     96
#                 ],
#                 [
#                     "1996",
#                     107
#                 ],
#                 [
#                     "1997",
#                     105
#                 ],
#                 [
#                     "1998",
#                     103
#                 ],
#                 [
#                     "1999",
#                     114
#                 ],
#                 [
#                     "2000",
#                     144
#                 ],
#                 [
#                     "2001",
#                     186
#                 ],
#                 [
#                     "2002",
#                     177
#                 ],
#                 [
#                     "2003",
#                     208
#                 ],
#                 [
#                     "2004",
#                     241
#                 ],
#                 [
#                     "2005",
#                     248
#                 ],
#                 [
#                     "2006",
#                     251
#                 ],
#                 [
#                     "2007",
#                     244
#                 ],
#                 [
#                     "2008",
#                     243
#                 ],
#                 [
#                     "2009",
#                     300
#                 ],
#                 [
#                     "2010",
#                     342
#                 ],
#                 [
#                     "2011",
#                     355
#                 ],
#                 [
#                     "2012",
#                     327
#                 ],
#                 [
#                     "2013",
#                     338
#                 ],
#                 [
#                     "2014",
#                     351
#                 ],
#                 [
#                     "2015",
#                     396
#                 ],
#                 [
#                     "2016",
#                     332
#                 ],
#                 [
#                     "2017",
#                     269
#                 ],
#                 [
#                     "2018",
#                     198
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": [
#                     {
#                         "type": "average",
#                         "name": "mean-Value"
#                     }
#                 ],
#                 "symbolSize": 10
#             },
#             "seriesId": 3762229
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "1976",
#                     7.43
#                 ],
#                 [
#                     "1977",
#                     7.45
#                 ],
#                 [
#                     "1978",
#                     7.99
#                 ],
#                 [
#                     "1979",
#                     7.92
#                 ],
#                 [
#                     "1980",
#                     8.36
#                 ],
#                 [
#                     "1981",
#                     7.84
#                 ],
#                 [
#                     "1982",
#                     7.5
#                 ],
#                 [
#                     "1983",
#                     7.79
#                 ],
#                 [
#                     "1984",
#                     7.53
#                 ],
#                 [
#                     "1985",
#                     7.43
#                 ],
#                 [
#                     "1986",

# %%
df_concat
# Out:
#                     剧名    年份                                             导演  \
# 0           天地风云录之决战时刻  2012                                            黄立纲
# 1            天地风云录之九龙变  2012                                            黄立纲
# 2           天地风云录之剑影魔踪  2013                                            黄立纲
# 3           霹雳兵燹之刀戟戡魔录  2005                                            黄文择
# 4          霹雳兵燹之刀戟戡魔录2  2005                                            黄文择
# 5                 霹雳剑踪  2005                                            黄文择
# 6           金光御九界之墨武侠锋  2014                                周俊豪 / 王钟庆 / 黄立纲
# 7           天地风云录之魔戮血战  2014                                            黄立纲
# 8                 霹雳狂刀  1993                                            黄文择
# 9                后山日先照  2002                                            李岳峰
# 10                 一把青  2015                                            曹瑞原
# 11                流氓教授  2001                                游坚煜 / 刘俊杰 / 欧阳升
# 12           玉琳国师之再世情缘  1992                                             勾峰
# 13               光阴的故事  2008                                      陈俊良 / 万东文
# 14             花甲男孩转大人  2017                                      瞿友宁 / 李青蓉
# 15            云州大儒侠史艳文  2000                                            黄立纲
# 16                草山春晖  2005                                            邓安宁
# 17                危险心灵  2006                                      易智言 / 杨雅_
# 18              新白娘子传奇  1992                                       夏祖辉 / 何麒
# 19          霹雳震寰宇之刀龙传说  2009                                            黄文择
# 20                名扬四海  2003                                            蔡岳勋
# 21                绿宫秘史  2013                                            陈奕仁
# 22    绝地花园：八个罕见病友的真情故事  2004  蔡明亮 / 李康生 / 王明台 / 瞿友_ / 杨雅_ / 王小棣 / 陈若菲 / 安哲毅
# 23               牵纸鹤的手  2010                                      许肇任 / 林志儒
# 24                霹雳异数  1990                                            黄文择
# 25                霹雳神州  2008                                            黄文择
# 26             我可能不会爱你  2011                                            瞿友宁
# 27               江湖奇侠传  1997                                      鞠觉亮 / 陈鸿烈
# 28           风中绯樱－雾社事件  2003                                             万仁
# 29                霹雳图腾  2004                                            黄文择
# ...                ...   ...                                            ...
# 6235               钟鼓楼  1986                                       鲁晓威 / 唐果
# 6236                新星  1986                                             李新
# 6237             倚天屠龙记  1986                                            王天林
# 6238              一代枭雄  1986
# 6239            乌龙山剿匪记  1986                                             宋昭
# 6240          康德第一保镖传奇  1986                 冀茂东 / 纪小黑 / 李建 / 郭枫 / 翟志杰 / 李杰
# 6241              在水一方  1986                                             小岛
# 6242            月朦胧鸟朦胧  1986                                            史蜀君
# 6243              努尔哈赤  1986                                            陈家林
# 6244              四世同堂  1985                                      林汝为 / 蔡洪德
# 6245               诸葛亮  1985                                            孙光明
# 6246                包公  1985                                      钱学格 / 顾琴芳
# 6247           寻找回来的世界  1985                                             许雷
# 6248                济公  1985                                             张戈
# 6249               秋海棠  1985                                            郭信玲
# 6250             铁道游击队  1985
# 6251            木鱼石的传说  1985                                            金守泰
# 6252              海灯法师  1985
# 6253           米老鼠和唐老鸭  1984                                         华特·迪士尼
# 6254            高山下的花环  1984                                      滕敬德 / 席与明
# 6255             黑豹突击队  1984                                       陈俊中 / 何为
# 6256           夜幕下的哈尔滨  1984                                       任豪 / 邵宏来
# 6257                蛙女  1984                                             牛_
# 6258           武松（山东版）  1983                                       刘柳 / 王俊洲
# 6259                水浒  1982                陈敏 / 王浚洲 / 刘柳 / 张新建 / 刘子云 / 王汉平
# 6260              蹉跎岁月  1982                                            蔡晓晴
# 6261             马可·波罗  1982                                     吉奥里亚诺·蒙塔尔多
# 6262               虾球传  1982
# 6263             敌营十八年  1981                                       王扶林 / 都郁
# 6264            七十二家房客  1978
#
#                                                  编剧  \
# 0                                       三弦、罗陵、苏玟、素文
# 1
# 2                                             三弦 素文
# 3
# 4
# 5
# 6                                      三弦 / 季电 / 傲绝
# 7                                           三弦 / 素文
# 8                                         黄强华 / 黄文择
# 9                                               __秋
# 10                                        黄世鸣 / 白先勇
# 11    林建隆 / 徐誉庭 / 周平之 / 林_俊 / 方静仪 / 杜政哲 / 赖正杰 / 彭盛青
# 12                                             星云大师
# 13                                              王伟忠
# 14                            杨富闵 / 杨璧莹 / 吴翰杰 / 詹俊杰
# 15                                        黄俊雄 / 黄凤仪
# 16
# 17          易智言 / 蔡宗翰 / 简士耕 / 郑仰山 / 王纪尧 / 雷建容 / 连凯鸿
# 18                  贡敏 / 赵文川 / 方桂兰 / 何冀平 / 夏祖辉 / 何麒
# 19                                              黄强华
# 20
# 21
# 22
# 23                            吕莳媛 / 林欣慧 / 吴维君 / 林纯华
# 24
# 25                                              黄强华
# 26                                              徐誉庭
# 27                                              丁善玺
# 28                                              邱若龙
# 29
# ...                                             ...
# 6235                                       周锴 / 鲁晓威
# 6236                                             李新
# 6237               谭_ / 关展博 / ___ / _惠玲 / 李_萍 / _柏能
# 6238
# 6239                                            水运宪
# 6240                                刘韩涛 / 纪小黑 / 齐铁雄
# 6241
# 6242                                            史蜀君
# 6243
# 6244                                             老舍
# 6245                                 邹云峰 / 王凯 / 胡三香
# 6246                                             亢君
# 6247                                        楚雪 / 战楠
# 6248                                            乔谷凡
# 6249                                      周以勤 / 秦瘦鸥
# 6250
# 6251                                            陶重华
# 6252
# 6253                                         华特·迪士尼
# 6254                                       李德顺 / 于景
# 6255
# 6256                                 任豪 / 焦乃积 / 王悦俭
# 6257                                胡万春 / 沈耀庭 / 孙雄飞
# 6258                                王汉平 / 赵长海 / 王俊洲
# 6259                                施耐庵 / 王汉平 / 赵长海
# 6260                                             叶辛
# 6261
# 6262                                      黄谷柳 / 张木桂
# 6263                                            唐佩琳
# 6264
#
#                                                      主演  \
# 0                               史艳文 / 藏镜人 / 神蛊温皇 / 黑白郎君
# 1
# 2
# 3                                                 黄文择口白
# 4                                                 黄文择口白
# 5                                                 黄文择口白
# 6
# 7
# 8                                                 黄文择口白
# 9                                       张美瑶 / 梁修身 / 江祖平
# 10    杨谨华 / 天心 / 连俞涵 / 吴慷仁 / 杨一展 / 蓝钧天 / 温贞菱 / 钟承翰 /...
# 11                     王识贤 / 潘仪君 / 杨烈 / 李_文 / 沈世朋 / 周幼婷
# 12                                 杨庆煌 / 况明洁 / 铁孟秋 / 曹健
# 13    陈怡蓉 / 赖雅妍 / 纪文蕙 / 小甜甜 / 杨一展 / 马念先 / 寇家瑞 / 林雨宣 ...
# 14    卢广仲 / 龙劭华 / 康晋荣 / 柯叔元 / 王彩桦 / 今子嫣 / 阮氏翠恒 / 海芬 ...
# 15                                                  黄俊雄
# 16                                      杨丽音 / 霍正奇 / 曾国城
# 17            黄河 / 桂纶镁 / 李烈 / 温升豪 / 高捷 / 关勇 / 张书豪 / 蔡灿得
# 18         赵雅芝 / 叶童 / 陈美琪 / 石乃文 / 夏光莉 / 乾德门 / 尹宝莲 / 阮虔芷
# 19                                                黄文择口白
# 20        尤秋兴 / 张惠春 / 虞小卉 / 唐治平 / 修杰楷 / 刘亮佐 / 蔡淑臻 / 黄芝琪
# 21                    史俊威 / 谢馨仪 / 龚钰祺 / 吴青峰 / 刘家凯 / 何景扬
# 22                                              _芳 / 高捷
# 23    吴中天 / 巫建和 / 陈靖婕 / 邓志鸿 / 林志儒 / 王月 / 丁也恬 / 吴朋奉 /...
# 24                                                黄文择口白
# 25                                                黄文择口白
# 26    林依晨 / 陈柏霖 / 王阳明 / 陈匡怡 / 陆明君 / 黄志玮 / 孟耿如 / 林美秀 ...
# 27                                       郑少秋 / 梁_ / 陈鸿烈
# 28                                      高慧君 / 马志翔 / _清喜
# 29                                                  黄文择
# ...                                                 ...
# 6235          郭平 / 孟瑾 / 刘艳臣 / 叶仲寅 / 吕中 / 郭霄珍 / 刘佳 / 田春奎
# 6236                                 周里京 / 鲁非 / 刘冬 / 梁彦
# 6237  梁朝伟 / 黎美娴 / 邓萃雯 / 邵美琪 / 郑裕玲 / 任达华 / 曾江 / 鲍方 / ...
# 6238                   王华 / 范冬雨 / 李芸 / 陈观泰 / 夏天 / 古扎丽努尔
# 6239  周琦 / 陈玛雅 / 刘烈红 / 陈家徒 / 安亚平 / 马军勤 / 姚未平 / 申军谊 /...
# 6240  张继波 / 阎莉莉 / 刘卫华 / 康静 / 左阳 / 张玫 / 石秀梅 / 林瑶 / 梁忠...
# 6241                                     李芸 / 马晓伟 / 王诗槐
# 6242                                     赵艳红 / 陈剑飞 / 宋佳
# 6243                                          候永生 / 傅艺伟
# 6244  邵华 / 李明 / 李婉芬 / 李维康 / 徐美玲 / 李文玲 / 谢钢 / 许正廷 / 陈...
# 6245                          李法曾 / 黄家德 / 郑军 / 张辛元 / 张章
# 6246                                                白志迪
# 6247               许亚军 / 宋丹丹 / 黄凯 / 闪增宏 / 李明珠 / 马静 / 王刚
# 6248                                           游本昌 / 吕凉
# 6249                                           龚雪 / 刘伟明
# 6250                   张甲田 / 王国强 / 张学浩 / 杨鸣健 / 牛娜 / 薛国平
# 6251                                      张运济 / 郑爽 / 巢萍
# 6252                    熊长贵 / 吴云华 / 苏冬花 / 李农 / 李宗儒 / 高鹏
# 6253                                            董浩 / 李扬
# 6254                                    周里京 / 朱建民 / 王同乐
# 6255  杨时辉 / 李保民 / 王家峰 / 王治军 / 赛家胜 / 高扬 / 李福全 / 钟伟 / ...
# 6256  林达信 / 王刚 / 迟重瑞 / 陈剑飞 / 张毅然 / 解衍 / 徐亚洲 / 郭寿阳 / ...
# 6257       宋佳 / 孙亚男 / 张孝中 / 臧金生 / 梁庆刚 / 杨宝河 / 张学津 / 余华东
# 6258                                                祝延平
# 6259                  于守金 / 祝延平 / 董子武 / 鲍国安 / 丁汝骏 / 彭荫泰
# 6260  郭旭新 / 赵越 / 肖雄 / 李龙吟 / 丛林 / 李林选 / 叶千荣 / 周虹 / 陈玛...
# 6261         肯·马歇尔 / 伯特·兰卡斯特 / 英若诚 / 伦纳德·尼莫伊 / 恩和森 / 苗苗
# 6262                               麦文燕 / 钟浩 / 卢海潮 / 闪增宏
# 6263  张连文 / 张甲田 / 刘玉 / 夏汉碧 / 沈红 / 梅承藻 / 马加奇 / 李小力 / ...
# 6264                         杨华生 / 王汝刚 / 张樵侬 / 绿杨 / 笑嘻嘻
#
#                                类型     制片国家/地区   集数 单集片长/分钟  豆瓣评分  评价人数/人
# 0                    剧情 / 动作 / 武侠          台湾   20      58   9.6     492
# 1                    奇幻 / 武侠 / 古装          台湾   36           9.6     485
# 2                    剧情 / 奇幻 / 武侠          台湾   20      60   9.5     364
# 3               剧情 / 动作 / 武侠 / 古装          台湾   30           9.4     710
# 4               剧情 / 动作 / 武侠 / 古装          台湾   40           9.4     608
# 5                       武侠 / 舞台艺术          台湾   30           9.4    1407
# 6                    奇幻 / 武侠 / 古装          台湾   32      90   9.4     345
# 7                         奇幻 / 武侠          台湾   34      75   9.3     338
# 8                              剧情          台湾   60      55   9.3     270
# 9                                          台湾   20           9.3      76
# 10                        剧情 / 爱情          台湾   31      50   9.3    9336
# 11                                         台湾   63      60   9.2      54
# 12                             古装          台湾   33           9.2     493
# 13                             剧情          台湾  107      45   9.2    5983
# 14                             剧情          台湾    7      95   9.2    2299
# 15                                         台湾   50           9.1     572
# 16                                         台湾   56           9.1      52
# 17                             剧情          台湾   30           9.1    1584
# 18                   爱情 / 奇幻 / 古装          台湾   50      49   9.0   90386
# 19    剧情 / 动作 / 科幻 / 武侠 / 古装 / 鬼怪          台湾   40      63   9.0     698
# 20                   剧情 / 爱情 / 家庭          台湾   28      60   9.0     546
# 21                             喜剧          台湾    5           9.0     227
# 22                             剧情          台湾    8           9.0      52
# 23                                         台湾   20           9.0      49
# 24                                         台湾   40      75   8.9     112
# 25                                         台湾   30           8.9     340
# 26                             爱情          台湾   13      90   8.9  144795
# 27                   历史 / 武侠 / 古装          台湾   59      45   8.9     524
# 28                                         台湾   20      50   8.8      40
# 29                                         台湾   20           8.8     133
# ...                           ...         ...  ...     ...   ...     ...
# 6235                           剧情        中国大陆    8      35   8.4     194
# 6236                           剧情        中国大陆   12           8.0     105
# 6237            剧情 / 动作 / 武侠 / 古装   香港 / 中国大陆   40      42   7.9    2073
# 6238                 动作 / 传记 / 武侠   中国大陆 / 香港   10           7.8      56
# 6239                           剧情        中国大陆   18      41   7.6    2342
# 6240                                     中国大陆   36           7.3      99
# 6241                                     中国大陆    4           7.1      71
# 6242                      剧情 / 爱情        中国大陆    6           7.0      46
# 6243                                     中国大陆   16           6.4     168
# 6244                      剧情 / 家庭        中国大陆   28      45   8.8    2013
# 6245                                     中国大陆   14           8.4     188
# 6246                           历史        中国大陆   18           8.1     101
# 6247               剧情 / 历史 / 黑色电影        中国大陆   12      50   8.1     574
# 6248                 喜剧 / 动作 / 古装        中国大陆   12      45   8.0   22208
# 6249                                     中国大陆   12           7.2     167
# 6250                                     中国大陆   12           6.8      43
# 6251                           剧情        中国大陆    6           6.8      79
# 6252                           剧情        中国大陆   16      50   6.6     583
# 6253                      喜剧 / 儿童    中国大陆 / 美  104           9.0    1104
# 6254                                     中国大陆    3           8.6     419
# 6255                                     中国大陆    4           7.8      62
# 6256                           剧情        中国大陆   13           7.3     186
# 6257                           剧情        中国大陆   14           6.7     281
# 6258                           古装        中国大陆    8           8.8      79
# 6259                      剧情 / 古装        中国大陆   40      50   8.1    1377
# 6260                                     中国大陆    4           7.8      91
# 6261                 传记 / 历史 / 冒险  意大利 / 中国大陆    8     495   7.8     202
# 6262                                     中国大陆    8           7.1     103
# 6263                           战争        中国大陆    9           7.4     167
# 6264                           喜剧        中国大陆    4           8.9     161
#
# [6214 rows x 11 columns]

# %% [markdown]
# # 2

# %%
tmp = df_concat[df_concat['年份'] > 2012]

# %%
tmp[tmp['评价人数/人'] > 100000].sort_values(by = '豆瓣评分', ascending = True).head(3)
# Out:
#           剧名    年份                     导演              编剧  \
# 2154    深夜食堂  2017              蔡岳勋 / 胡涵清             陈怡方
# 2155  漂亮的李慧珍  2017                    赵晨阳        卢至柔 / 杨青
# 2321     青云志  2016  朱锐斌 / 周远舟 / 刘国辉 / 朱少杰  邵潇逸 / 张少微 / 张戬
#
#                                                      主演            类型 制片国家/地区  \
# 2154  黄磊 / 赵又廷 / 张钧甯 / 海清 / 何炅 / 陈意涵 / 马苏 / 刘昊然 / 萧敬...            剧情    中国大陆
# 2155  迪丽热巴 / 盛一伦 / 李溪芮 / 张彬彬 / 王骁 / 王一楠 / 任伟 / 王一菲 /...       喜剧 / 爱情    中国大陆
# 2321  李易峰 / 赵丽颖 / 杨紫 / 舒畅 / 王源 / 王俊凯 / 易烊千玺 / 熊乃瑾 / ...  奇幻 / 武侠 / 古装    中国大陆
#
#       集数 单集片长/分钟  豆瓣评分  评价人数/人
# 2154  36      45   2.8  104240
# 2155  40      43   2.8  109354
# 2321  55      45   5.3  122359

# %%
tmp[tmp['评价人数/人'] > 100000].sort_values(by = '豆瓣评分', ascending = False).head(3)
# Out:
#         剧名    年份       导演        编剧  \
# 2436   琅琊榜  2015  孔笙 / 李雪        海宴
# 1941  白夜追凶  2017       王伟  指纹 / 顾小白
# 2444   伪装者  2015       李雪        张勇
#
#                                                      主演            类型 制片国家/地区  \
# 2436  胡歌 / 刘涛 / 王凯 / 陈龙 / 黄维德 / 靳东 / 高鑫 / 张_琰 / 张龄心 ...       剧情 / 古装    中国大陆
# 1941  潘粤明 / 王泷正 / 梁缘 / 吕晓霖 / 尹姝贻 / 侯雪龙 / 宋乃刚 / 王余阳 /...  剧情 / 悬疑 / 犯罪    中国大陆
# 2444  胡歌 / 靳东 / 刘敏涛 / 王凯 / 宋轶 / 王乐君 / 王鸥 / 刘奕君 / 岳_ ...       剧情 / 悬疑    中国大陆
#
#       集数 单集片长/分钟  豆瓣评分  评价人数/人
# 2436  54      45   9.2  256604
# 1941  32      45   9.0  245310
# 2444  48      40   8.4  100309

# %% [markdown]
# # 3

# %%
def style_quantity(df):
    styles = []
    for i in df['类型']:
        style = i.split(' / ')
        for j in style:
            if j != '':
                styles.append(j)
    tmp = pd.DataFrame({'styles': styles})['styles'].value_counts()
    results = pd.DataFrame({'类型': tmp.index, '总部数': tmp.values})
    results.drop(0, inplace = True)
    return results

# %%
def display_bar(df, area):
    x = style_quantity(df)['类型'][:10]
    y = style_quantity(df)['总部数'][:10]
    bar = Bar(area)
    bar.add('总部数', x, y, is_label_show = True, xaxis_interval = 0)
    return bar

# %%
display_bar(df_tw, '台湾')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="7b18a81c3e7741f2b1f33574705558b4" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_7b18a81c3e7741f2b1f33574705558b4 = echarts.init(document.getElementById('7b18a81c3e7741f2b1f33574705558b4'), 'light', {renderer: 'canvas'});
#
# var option_7b18a81c3e7741f2b1f33574705558b4 = {
#     "title": [
#         {
#             "text": "\u53f0\u6e7e",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6774034,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u90e8\u6570",
#             "data": [
#                 337.0,
#                 99.0,
#                 94.0,
#                 90.0,
#                 45.0,
#                 36.0,
#                 34.0,
#                 20.0,
#                 18.0,
#                 16.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6774034
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u90e8\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7231\u60c5",
#                 "\u53e4\u88c5",
#                 "\u559c\u5267",
#                 "\u6b66\u4fa0",
#                 "\u5947\u5e7b",
#                 "\u52a8\u4f5c",
#                 "\u5bb6\u5ead",
#                 "\u5386\u53f2",
#                 "\u540c\u6027",
#                 "\u60ac\u7591"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_7b18a81c3e7741f2b1f33574705558b4.setOption(option_7b18a81c3e7741f2b1f33574705558b4);
#
#     });
# </script>

# %%
display_bar(df_hk, '香港')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="142cfd8e4863461b9b4b79e5e9e95e37" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_142cfd8e4863461b9b4b79e5e9e95e37 = echarts.init(document.getElementById('142cfd8e4863461b9b4b79e5e9e95e37'), 'light', {renderer: 'canvas'});
#
# var option_142cfd8e4863461b9b4b79e5e9e95e37 = {
#     "title": [
#         {
#             "text": "\u9999\u6e2f",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2309826,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u90e8\u6570",
#             "data": [
#                 263.0,
#                 188.0,
#                 164.0,
#                 100.0,
#                 90.0,
#                 89.0,
#                 70.0,
#                 59.0,
#                 42.0,
#                 39.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2309826
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u90e8\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7231\u60c5",
#                 "\u559c\u5267",
#                 "\u53e4\u88c5",
#                 "\u6b66\u4fa0",
#                 "\u72af\u7f6a",
#                 "\u52a8\u4f5c",
#                 "\u60ac\u7591",
#                 "\u5bb6\u5ead",
#                 "\u5386\u53f2",
#                 "\u5947\u5e7b"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_142cfd8e4863461b9b4b79e5e9e95e37.setOption(option_142cfd8e4863461b9b4b79e5e9e95e37);
#
#     });
# </script>

# %%
display_bar(df_ml, '大陆')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="c0f8d319477341bd81d1716c6c436335" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_c0f8d319477341bd81d1716c6c436335 = echarts.init(document.getElementById('c0f8d319477341bd81d1716c6c436335'), 'light', {renderer: 'canvas'});
#
# var option_c0f8d319477341bd81d1716c6c436335 = {
#     "title": [
#         {
#             "text": "\u5927\u9646",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 6092197,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u90e8\u6570",
#             "data": [
#                 1143.0,
#                 609.0,
#                 567.0,
#                 479.0,
#                 382.0,
#                 317.0,
#                 289.0,
#                 183.0,
#                 171.0,
#                 169.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 6092197
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u90e8\u6570"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u7231\u60c5",
#                 "\u53e4\u88c5",
#                 "\u559c\u5267",
#                 "\u5bb6\u5ead",
#                 "\u6218\u4e89",
#                 "\u5386\u53f2",
#                 "\u60ac\u7591",
#                 "\u72af\u7f6a",
#                 "\u5947\u5e7b",
#                 "\u52a8\u4f5c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_c0f8d319477341bd81d1716c6c436335.setOption(option_c0f8d319477341bd81d1716c6c436335);
#
#     });
# </script>

# %%
name = style_quantity(df_concat)['类型']
value = style_quantity(df_concat)['总部数']
wordcloud = WordCloud('总体')
wordcloud.add('', name, value, shape = 'circle', word_size_range = [20, 100])
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min', 'wordcloud': '/nbextensions/echarts/echarts-wordcloud.min'
#         }
#     });
# </script>
#     <div id="c9cc677aa65347a7aa97390be5ec642e" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts', 'wordcloud'], function(echarts) {
#
# var myChart_c9cc677aa65347a7aa97390be5ec642e = echarts.init(document.getElementById('c9cc677aa65347a7aa97390be5ec642e'), 'light', {renderer: 'canvas'});
#
# var option_c9cc677aa65347a7aa97390be5ec642e = {
#     "title": [
#         {
#             "text": "\u603b\u4f53",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 3390947,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "wordCloud",
#             "shape": "circle",
#             "rotationRange": [
#                 -90,
#                 90
#             ],
#             "rotationStep": 45,
#             "girdSize": 20,
#             "sizeRange": [
#                 20,
#                 100
#             ],
#             "data": [
#                 {
#                     "name": "\u7231\u60c5",
#                     "value": 1717,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(63,5,123)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u53e4\u88c5",
#                     "value": 861,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(46,57,74)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u559c\u5267",
#                     "value": 842,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,156,11)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5bb6\u5ead",
#                     "value": 570,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(160,32,107)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6218\u4e89",
#                     "value": 393,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(53,66,149)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60ac\u7591",
#                     "value": 374,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(117,87,13)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5386\u53f2",
#                     "value": 373,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(66,64,52)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6b66\u4fa0",
#                     "value": 324,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,111,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u52a8\u4f5c",
#                     "value": 290,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(37,87,90)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u72af\u7f6a",
#                     "value": 276,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(138,154,5)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5947\u5e7b",
#                     "value": 251,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(88,54,95)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u4f20\u8bb0",
#                     "value": 123,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(158,79,89)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u60ca\u609a",
#                     "value": 69,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(58,17,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u513f\u7ae5",
#                     "value": 65,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(36,38,96)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u79d1\u5e7b",
#                     "value": 62,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(105,42,40)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u77ed\u7247",
#                     "value": 55,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(97,47,133)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u5192\u9669",
#                     "value": 46,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(154,135,139)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u6050\u6016",
#                     "value": 27,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(5,56,92)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u540c\u6027",
#                     "value": 25,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(102,94,58)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u8fd0\u52a8",
#                     "value": 19,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(137,8,16)"
#                         }
#                     }
#                 },
#                 {
#                     "name": "\u620f\u66f2",
#                     "value": 15,
#                     "textStyle": {
#                         "normal": {
#                             "color": "rgb(130,155,66)"

# %% [markdown]
# # 4

# %%
def actor_score_number(df):
    actors = []
    scores = []
    for i in df.index:
        tmp = (df['主演'][i].split(' / '), df['豆瓣评分'][i])
        for actor in tmp[0]:
            if actor != '':
                actors.append(actor)
                scores.append(tmp[1])
    datas = pd.DataFrame({'actors': actors, 'scores': scores})
    actors = datas.actors.drop_duplicates()
    my1 = []
    my2 = []
    my3 = []
    for actor in actors:
        my1.append(actor)
        tmp = datas[datas.actors == actor]
        my2.append(round(tmp.scores.sum() / len(tmp), 2))
        my3.append(len(tmp))
    results = pd.DataFrame({'演员': my1, '平均分': my2, '部数': my3}).sort_values('平均分', ascending = False)
    return results

# %%
# actor_score_number(df_concat).to_csv('dataset/演员-平均分-部数.csv', index = False, encoding = 'gbk')

# %%
df = pd.read_csv(open('dataset/演员-平均分-部数.csv',encoding = 'gbk'))

# %%
wb90s = pd.DataFrame({'演员': [item[0] for item in weibo90s().items()], '粉丝数': [item[1] for item in weibo90s().items()]})
wbfans30 = pd.DataFrame({'演员': [item[0] for item in weibofans30().items()], '粉丝数': [item[1] for item in weibofans30().items()]})
wb90s = pd.merge(wb90s, df)
wbfans30 = pd.merge(wbfans30, df)

# %%
# wbfans30 = wbfans30.sort_values(by = '部数',ascending = False)
# wb90s = wb90s.sort_values(by = '部数',ascending = False)

# %%
def display_overlap(df, name):
    x = df['演员']
    y1 = df['部数']
    y2 = df['平均分']
    bar = Bar(name, '注：横坐标依据粉丝数从大到小排列')
    line = Line()
    bar.add('部数', x, y1, xaxis_interval = 0, is_datazoom_show = True, datazoom_range = [0, 50])
    line.add('平均分', x, y2, is_label_show = True)
    overlap = Overlap()
    overlap.add(bar)
#     overlap.add(line)
    overlap.add(line, yaxis_index=1, is_add_yaxis=True)
    return overlap

# %%
display_overlap(wb90s, '微博九零后')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="de1c20f895a1446b9327ab69c04a2104" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_de1c20f895a1446b9327ab69c04a2104 = echarts.init(document.getElementById('de1c20f895a1446b9327ab69c04a2104'), 'light', {renderer: 'canvas'});
#
# var option_de1c20f895a1446b9327ab69c04a2104 = {
#     "title": [
#         {
#             "text": "\u5fae\u535a\u4e5d\u96f6\u540e",
#             "subtext": "\u6ce8\uff1a\u6a2a\u5750\u6807\u4f9d\u636e\u7c89\u4e1d\u6570\u4ece\u5927\u5230\u5c0f\u6392\u5217",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1268633,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u90e8\u6570",
#             "data": [
#                 2.0,
#                 14.0,
#                 20.0,
#                 25.0,
#                 2.0,
#                 16.0,
#                 19.0,
#                 4.0,
#                 9.0,
#                 4.0,
#                 5.0,
#                 25.0,
#                 4.0,
#                 16.0,
#                 9.0,
#                 8.0,
#                 5.0,
#                 17.0,
#                 1.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1268633
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u9e7f\u6657",
#                     3.5
#                 ],
#                 [
#                     "\u8fea\u4e3d\u70ed\u5df4",
#                     5.02
#                 ],
#                 [
#                     "\u6768\u6d0b",
#                     5.6
#                 ],
#                 [
#                     "\u6768\u7d2b",
#                     6.78
#                 ],
#                 [
#                     "\u9ec4\u5b50\u97ec",
#                     3.35
#                 ],
#                 [
#                     "\u5434\u78ca",
#                     6.15
#                 ],
#                 [
#                     "\u5f20\u4e00\u5c71",
#                     6.89
#                 ],
#                 [
#                     "\u9648\u5b66\u51ac",
#                     3.85
#                 ],
#                 [
#                     "\u9093\u4f26",
#                     6.3
#                 ],
#                 [
#                     "\u5468\u51ac\u96e8",
#                     4.75
#                 ],
#                 [
#                     "\u5218\u660a\u7136",
#                     6.8
#                 ],
#                 [
#                     "\u5173\u6653\u5f64",
#                     6.14
#                 ],
#                 [
#                     "\u767d\u656c\u4ead",
#                     6.72
#                 ],
#                 [
#                     "\u674e\u6c81",
#                     5.97
#                 ],
#                 [
#                     "\u848b\u52b2\u592b",
#                     5.38
#                 ],
#                 [
#                     "\u53e4\u529b\u5a1c\u624e",
#                     4.56
#                 ],
#                 [
#                     "\u5f20\u5929\u7231",
#                     5.18
#                 ],
#                 [
#                     "\u8c2d\u677e\u97f5",
#                     6.4
#                 ],
#                 [
#                     "\u6b27\u9633\u5a1c\u5a1c",
#                     2.6
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1268633,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u90e8\u6570",
#                 "\u5e73\u5747\u5206"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "data": [
#                 "\u9e7f\u6657",
#                 "\u8fea\u4e3d\u70ed\u5df4",
#                 "\u6768\u6d0b",
#                 "\u6768\u7d2b",
#                 "\u9ec4\u5b50\u97ec",
#                 "\u5434\u78ca",
#                 "\u5f20\u4e00\u5c71",
#                 "\u9648\u5b66\u51ac",
#                 "\u9093\u4f26",
#                 "\u5468\u51ac\u96e8",
#                 "\u5218\u660a\u7136",
#                 "\u5173\u6653\u5f64",
#                 "\u767d\u656c\u4ead",
#                 "\u674e\u6c81",
#                 "\u848b\u52b2\u592b",
#                 "\u53e4\u529b\u5a1c\u624e",
#                 "\u5f20\u5929\u7231",
#                 "\u8c2d\u677e\u97f5",
#                 "\u6b27

# %%
display_overlap(wbfans30, '微博粉丝榜')
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="57d8fbde09c34ad09c78f0b05908a8b6" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_57d8fbde09c34ad09c78f0b05908a8b6 = echarts.init(document.getElementById('57d8fbde09c34ad09c78f0b05908a8b6'), 'light', {renderer: 'canvas'});
#
# var option_57d8fbde09c34ad09c78f0b05908a8b6 = {
#     "title": [
#         {
#             "text": "\u5fae\u535a\u7c89\u4e1d\u699c",
#             "subtext": "\u6ce8\uff1a\u6a2a\u5750\u6807\u4f9d\u636e\u7c89\u4e1d\u6570\u4ece\u5927\u5230\u5c0f\u6392\u5217",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 1106485,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u90e8\u6570",
#             "data": [
#                 14.0,
#                 5.0,
#                 37.0,
#                 4.0,
#                 22.0,
#                 17.0,
#                 11.0,
#                 51.0,
#                 25.0,
#                 21.0,
#                 17.0,
#                 15.0,
#                 22.0,
#                 33.0,
#                 30.0,
#                 24.0,
#                 40.0,
#                 11.0,
#                 28.0,
#                 12.0,
#                 27.0,
#                 2.0,
#                 36.0,
#                 2.0,
#                 20.0,
#                 14.0,
#                 18.0,
#                 17.0,
#                 6.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1106485
#         },
#         {
#             "type": "line",
#             "name": "\u5e73\u5747\u5206",
#             "symbol": "emptyCircle",
#             "symbolSize": 4,
#             "smooth": false,
#             "step": false,
#             "showSymbol": true,
#             "data": [
#                 [
#                     "\u8c22\u5a1c",
#                     6.19
#                 ],
#                 [
#                     "\u4f55\u7085",
#                     5.72
#                 ],
#                 [
#                     "\u6768\u5e42",
#                     6.2
#                 ],
#                 [
#                     "\u6768\u9896",
#                     4.03
#                 ],
#                 [
#                     "\u9648\u5764",
#                     7.42
#                 ],
#                 [
#                     "\u8d75\u8587",
#                     7.16
#                 ],
#                 [
#                     "\u59da\u6668",
#                     8.13
#                 ],
#                 [
#                     "\u6797\u5fc3\u5982",
#                     6.67
#                 ],
#                 [
#                     "\u8d75\u4e3d\u9896",
#                     5.92
#                 ],
#                 [
#                     "\u9093\u8d85",
#                     7.16
#                 ],
#                 [
#                     "\u6797\u5fd7\u9896",
#                     6.55
#                 ],
#                 [
#                     "\u90ed\u5fb7\u7eb2",
#                     6.64
#                 ],
#                 [
#                     "\u9648\u4e54\u6069",
#                     5.8
#                 ],
#                 [
#                     "\u5510\u5ae3",
#                     5.8
#                 ],
#                 [
#                     "\u8d3e\u4e43\u4eae",
#                     6.13
#                 ],
#                 [
#                     "\u80e1\u6b4c",
#                     7.33
#                 ],
#                 [
#                     "\u8303\u51b0\u51b0",
#                     6.74
#                 ],
#                 [
#                     "\u7f57\u5fd7\u7965",
#                     6.5
#                 ],
#                 [
#                     "\u9ec4\u6653\u660e",
#                     6.29
#                 ],
#                 [
#                     "\u9648\u8d6b",
#                     6.04
#                 ],
#                 [
#                     "\u6587\u7ae0",
#                     6.84
#                 ],
#                 [
#                     "\u9e7f\u6657",
#                     3.5
#                 ],
#                 [
#                     "\u674e\u6668",
#                     7.17
#                 ],
#                 [
#                     "\u97e9\u5e9a",
#                     6.5
#                 ],
#                 [
#                     "\u5218\u70e8",
#                     6.65
#                 ],
#                 [
#                     "\u8fea\u4e3d\u70ed\u5df4",
#                     5.02
#                 ],
#                 [
#                     "\u674e\u6613\u5cf0",
#                     6.22
#                 ],
#                 [
#                     "\u9ad8\u5706\u5706",
#                     7.36
#                 ],
#                 [
#                     "\u6797\u66f4\u65b0",
#                     6.0
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "lineStyle": {
#                 "normal": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 1106485,
#             "xAxisIndex": 0,
#             "yAxisIndex": 1
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u90e8\u6570",
#                 "\u5e73\u5747\u5206"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "in

# %% [markdown]
# # 5

# %%
df_hot = df_concat[df_concat['评价人数/人'] > 100000]

# %%
def actor_number(df):
    actors = []
    for i in df['主演']:
        tmp = i.split(' / ')
        for actor in tmp:
            if (actor != '') & (actor.find('_') == -1):
                actors.append(actor)
    datas = pd.DataFrame({'actors': actors})
    results = pd.DataFrame({'演员': datas.actors.value_counts().index, '部数': datas.actors.value_counts().values})
    results = results[results['部数'] > 1]
    return results

# %%
def find_nodes(df):
    tmp = actor_number(df)
    nodes = []
    for i in tmp.index:
        dic = {}
        dic['name'] = tmp['演员'][i]
        dic['value'] = tmp['部数'][i]
        dic['symbolSize'] = tmp['部数'][i] * 3
        nodes.append(dic)
    return nodes

# %%
nodes_hot = find_nodes(df_hot)

# %%
def actor_list(df):
    results = []
    for actors in df['主演']:
        if actors != '':
            result = []
            for actor in actors.split(' / '):
                if (actor != '') & (actor.find('_') == -1):
                    result.append(actor)
            results.append(result)
    return results

# %%
def find_df(df):
    tmp = actor_list(df)
    source = []
    target = []
    for actors in tmp:
        for i in range(len(actors)-1):
            for j in actors[i+1:]:
                source.append(actors[i])
                target.append(j)
    results = pd.DataFrame({'source': source, 'target': target})
    return results

# %%
links_hot = []
for index, row in find_df(df_hot).iterrows():
    source = row.source
    target = row.target
    links_hot.append({'source': source, 'target': target})

# %%
def display_graph(nodes, links):
    graph = Graph('热门电视剧演员关系图')
    graph.add('', nodes, links)
    return graph

# %%
display_graph(nodes_hot, links_hot).render('热门电视剧演员关系图.html')

# %% [markdown]
# # 6

# %%
datas = pd.read_csv('dataset/tmp.csv', encoding = 'gbk')
results = pd.DataFrame(index = datas['年份'].drop_duplicates().sort_values())

# %%
def add_column(area):
    column = []
    for year in results.index:
        column.append(len(datas[(datas['年份'] == year) & (datas['制片国家/地区'] == area)]))
    results[area] = column

# %%
areas = ['香港 / 台湾', '中国大陆 / 香港', '中国大陆 / 台湾', '中国大陆 / 香港 / 台湾']
for area in areas:
    add_column(area)

# %%
results
# Out:
#       香港 / 台湾  中国大陆 / 香港  中国大陆 / 台湾  中国大陆 / 香港 / 台湾
# 年份
# 1986        0          2          0               0
# 1990        0          1          0               0
# 1991        0          0          1               0
# 1993        1          1          0               1
# 1994        0          0          0               1
# 1995        1          1          2               0
# 1996        1          4          1               2
# 1997        0          3          0               0
# 1998        1          2          5               1
# 1999        0          2          6               0
# 2000        2          2          3               1
# 2001        2          2          3               0
# 2002        1          3          1               0
# 2003        1          1          4               2
# 2004        1          1          1               1
# 2005        1          5          4               1
# 2006        0          3          4               0
# 2007        0          3          7               0
# 2008        0          4          1               0
# 2009        0          0          3               1
# 2010        0          1          3               0
# 2011        0          2          6               0
# 2012        0          2          1               0
# 2013        0          1          1               0
# 2014        1          1          2               0
# 2015        0          1          2               0
# 2016        0          1          3               0
# 2017        0          3          0               0
# 2018        0          6          1               0

# %%
es = EffectScatter('三地合作情况图', '注：纵坐标代表合作程度，值越大表示合作次数越多')
x = results.index
def add_es(area):
    values = []
    for value in results[area].values:
        if value == 0:
            values.append(None)
        else:
            values.append(value)
    y = values
    es.add(area, x, y, xaxis_min = 1985, xaxis_max = 2020, xaxis_force_interval = 5)

# %%
for area in areas:
    add_es(area)

# %%
es
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="f163c1e9e91144eead2028879aa44f54" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_f163c1e9e91144eead2028879aa44f54 = echarts.init(document.getElementById('f163c1e9e91144eead2028879aa44f54'), 'light', {renderer: 'canvas'});
#
# var option_f163c1e9e91144eead2028879aa44f54 = {
#     "title": [
#         {
#             "text": "\u4e09\u5730\u5408\u4f5c\u60c5\u51b5\u56fe",
#             "subtext": "\u6ce8\uff1a\u7eb5\u5750\u6807\u4ee3\u8868\u5408\u4f5c\u7a0b\u5ea6\uff0c\u503c\u8d8a\u5927\u8868\u793a\u5408\u4f5c\u6b21\u6570\u8d8a\u591a",
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7713908,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "effectScatter",
#             "name": "\u9999\u6e2f / \u53f0\u6e7e",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     1986,
#                     null
#                 ],
#                 [
#                     1990,
#                     null
#                 ],
#                 [
#                     1991,
#                     null
#                 ],
#                 [
#                     1993,
#                     1.0
#                 ],
#                 [
#                     1994,
#                     null
#                 ],
#                 [
#                     1995,
#                     1.0
#                 ],
#                 [
#                     1996,
#                     1.0
#                 ],
#                 [
#                     1997,
#                     null
#                 ],
#                 [
#                     1998,
#                     1.0
#                 ],
#                 [
#                     1999,
#                     null
#                 ],
#                 [
#                     2000,
#                     2.0
#                 ],
#                 [
#                     2001,
#                     2.0
#                 ],
#                 [
#                     2002,
#                     1.0
#                 ],
#                 [
#                     2003,
#                     1.0
#                 ],
#                 [
#                     2004,
#                     1.0
#                 ],
#                 [
#                     2005,
#                     1.0
#                 ],
#                 [
#                     2006,
#                     null
#                 ],
#                 [
#                     2007,
#                     null
#                 ],
#                 [
#                     2008,
#                     null
#                 ],
#                 [
#                     2009,
#                     null
#                 ],
#                 [
#                     2010,
#                     null
#                 ],
#                 [
#                     2011,
#                     null
#                 ],
#                 [
#                     2012,
#                     null
#                 ],
#                 [
#                     2013,
#                     null
#                 ],
#                 [
#                     2014,
#                     1.0
#                 ],
#                 [
#                     2015,
#                     null
#                 ],
#                 [
#                     2016,
#                     null
#                 ],
#                 [
#                     2017,
#                     null
#                 ],
#                 [
#                     2018,
#                     null
#                 ]
#             ],
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "seriesId": 7713908
#         },
#         {
#             "type": "effectScatter",
#             "name": "\u4e2d\u56fd\u5927\u9646 / \u9999\u6e2f",
#             "showEffectOn": "render",
#             "rippleEffect": {
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             },
#             "symbol": "circle",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     1986,
#                     2.0
#                 ],
#                 [
#                     1990,
#                     1.0
#                 ],
#                 [
#                     1991,
#                     null
#                 ],
#                 [
#                     1993,
#                     1.0
#                 ],
#                 [
#                     1994,
#                     null
#                 ],
#                 [
#                     1995,
#                     1.0
#                 ],
#                 [
#                     1996,
#                     4.0
#                 ],
#                 [
#                     1997,
#                     3.0
#                 ],
#                 [
#                     1998,
#                     2.0
#                 ],
#                 [
#                     1999,
#                     2.0
#                 ],
#                 [
#                     2000,
#                     2.0
#                 ],
#                 [
#                     2001,
#                     2.0
#                 ],
#                 [
#                     2002,
#                     3.0
#                 ],
#                 [
#                     2003,
#                     1.0
#                 ],
#                 [
#                     2004,
#                     1.0
#                 ],
#                 [
#                     2005,
#                     5.0
#                 ],
#                 [
#                     2006,
#                     3.0
#                 ],
#                 [
#                     2007,
#                     3.0
#                 ],
#                 [
#                     2008,
#                     4.0
#                 ],
#                 [
#                     2009,
#                     null
#                 ],
#                 [
#                     2010,
#                     1.0
#                 ],
#                 [
#                     2011,
#                     2.0
#                 ],
#                 [
#                     2012,
#                     2.0
#                 ],
#                 [
#                     2013,
#                     1.0
#                 ],
#                 [
#                     2014,
#                     1.0
#                 ],
#                 [
#                     2015,
#                     1.0
#                 ],
#                 [
#                     2016,
#                     1.0
#                 ],
#                 [
#                     2017,
#                     3.0

# %% [markdown]
# # 7
